# %% [markdown]
# # Connect Intensive - Machine Learning Nanodegree
# # Lesson 2: Datasets and Questions- Enron Dataset Mini-Project
#
# ## Objectives
#   - Work through the Datasets and Questions lesson from [ud-120](https://www.udacity.com/course/intro-to-machine-learning--ud120) within the Jupyter Notebook environment
#   - Introduce [the `pickle` module](https://docs.python.org/2/library/pickle.html) from the Python Standard Library for preserving data structures in Python
#   - Practice loading data from different directories
#   - Review stacking and unstacking in `pandas` to [reshape a `DataFrame`](http://pandas.pydata.org/pandas-docs/stable/reshaping.html)
#   - Explore and understand data sets, particularly those with many missing values
#
# ## Prerequisites
#   - You should be familiar with `pandas` (lesson 1 in the [UConnect-Intensive repo](https://github.com/ryanjferrin/UConnect-Intensive))

# %% [markdown]
# ## Background
#
# The Enron fraud is a big, messy and totally fascinating story about corporate malfeasance of nearly every imaginable type. The Enron email and financial datasets are also big, messy treasure troves of information, which become much more useful once you know your way around them a bit. The Udacity team has combined the email and finance data into a single dataset, which you’ll explore in this mini-project.
#
#
# In the online course [Katie Malone](http://blog.udacity.com/2016/04/women-in-machine-learning-katie-malone.html) discusses the Enron scandal, introduces the Enron email corpus and defines and identifies a person-of-interest (POI).
#
# **POI**: Indicted, settled without admitting guilt, testified in exchange for immunity.
#
# **Goal**: Use machine learning to answer the question:
#
# **"Can we identify patterns in the emails of people who were POIs?"**

# %% [markdown]
# ## Getting Started
# The Datasets and Questions lesson in the Data Modeling section is based on Enron finance and email data. These datasets are located in the [**ud120-projects** repo](https://github.com/udacity/ud120-projects) on GitHub. Please clone the **ud120-projects** repo to your local machine.

# %% [markdown]
# ## Pickle
#  [The `pickle` module](https://docs.python.org/2/library/pickle.html) is a fast, efficient way to preserve (or pickle) data structures (*e.g.* dictionaries, lists, tuples, sets...), without having to structure or organize your output file. `Pickle` will know exactly how to serialize (or write) those structures to file. You can un-pickle the data structures using `pickle.load()`.
#
#
# More details regarding `pickle` can be found here-[this reference on Serializing Python Objects](http://www.diveintopython3.net/serializing.html) from Dive Into Python 3.
#
# **Run** the cell below to import the `pickle` module. (**shift + enter** or **shift + return**)

# %%
try:
    import pickle
    print("Successfully imported pickle!")
except ImportError:
    print("Could not import pickle")
# Out:
# Successfully imported pickle!

# %% [markdown]
# ## Update working directory
#
# The [Magic Function](http://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magics-explained) `%cd "..."` changes the working directory in the Jupyter Notebook.
#
# **Update** the Magic Function `%cd "..."` in the cell below to indicate the correct path of the **ud120-projects** directory on your local machine.
#
# Then **run** the cell below to load the Enron data!

# %%
# Ensure that you write the full path, up to and including "ud120-projects"
# %cd "../../../datasets/ud120-projects"

try:
    enron_data = pickle.load(open("final_project/final_project_dataset.pkl", "r")) # May require "rb" instead of "r"
    print("Enron dataset loaded succesfully!")
except IOError:
    print("Enron dataset not loaded")
# Out:
# [Errno 2] No such file or directory: '../../../datasets/ud120-projects'
# /Users/harrisleow/Desktop/Udacity_Connect_intensive/datasets/ud120-projects
# Enron dataset loaded succesfully!

# %% [markdown]
# ## Transforming data from Dictionary to DataFrame
# The variable `enron_data` is a dictionary object. Dictionaries are not displayed as nicely as `pandas` `DataFrame` objects within the Jupyter Notebook environment. Let's convert `enron_data` to a `DataFrame` object.
#
# Use either [the method `pandas.DataFrame.from_dict()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.from_dict.html) or simply use [the constructor `pandas.DataFrame()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) either works.
#
# **Run** the cell below to:
#   - import `pandas` and `display`.
#   - set some display options.
#   - create a `DataFrame` object for the Enron data.
#   - display the Enron data.

# %%
try:
    import pandas as pd
    print("Successfully imported pandas! (Version {})".format(pd.__version__))
    pd.options.display.max_rows = 100
except ImportError:
    print("Could not import pandas!")

try:
    from IPython.display import display
    print("Successfully imported display from IPython.display!")
except ImportError:
    print("Could not import display from IPython.display")
    
enron_df = pd.DataFrame.from_dict(enron_data)
display(enron_df)
print enron_df
# Out:
# Successfully imported pandas! (Version 0.19.2)
# Successfully imported display from IPython.display!
#                                    ALLEN PHILLIP K BADUM JAMES P  \
# bonus                                      4175000           NaN
# deferral_payments                          2869717        178980
# deferred_income                           -3081055           NaN
# director_fees                                  NaN           NaN
# email_address              phillip.allen@enron.com           NaN
# exercised_stock_options                    1729541        257817
# expenses                                     13868          3486
# from_messages                                 2195           NaN
# from_poi_to_this_person                         47           NaN
# from_this_person_to_poi                         65           NaN
# loan_advances                                  NaN           NaN
# long_term_incentive                         304805           NaN
# other                                          152           NaN
# poi                                          False         False
# restricted_stock                            126027           NaN
# restricted_stock_deferred                  -126027           NaN
# salary                                      201955           NaN
# shared_receipt_with_poi                       1407           NaN
# to_messages                                   2902           NaN
# total_payments                             4484442        182466
# total_stock_value                          1729541        257817
#
#                                    BANNANTINE JAMES M BAXTER JOHN C  \
# bonus                                             NaN       1200000
# deferral_payments                                 NaN       1295738
# deferred_income                                 -5104      -1386055
# director_fees                                     NaN           NaN
# email_address              james.bannantine@enron.com           NaN
# exercised_stock_options                       4046157       6680544
# expenses                                        56301         11200
# from_messages                                      29           NaN
# from_poi_to_this_person                            39           NaN
# from_this_person_to_poi                             0           NaN
# loan_advances                                     NaN           NaN
# long_term_incentive                               NaN       1586055
# other                                          864523       2660303
# poi                                             False         False
# restricted_stock                              1757552       3942714
# restricted_stock_deferred                     -560222           NaN
# salary                                            477        267102
# shared_receipt_with_poi                           465           NaN
# to_messages                                       566           NaN
# total_payments                                 916197       5634343
# total_stock_value                             5243487      10623258
#
#                                 BAY FRANKLIN R BAZELIDES PHILIP J  \
# bonus                                   400000                NaN
# deferral_payments                       260455             684694
# deferred_income                        -201641                NaN
# director_fees                              NaN                NaN
# email_address              frank.bay@enron.com                NaN
# exercised_stock_options                    NaN            1599641
# expenses                                129142                NaN
# from_messages                              NaN                NaN
# from_poi_to_this_person                    NaN                NaN
# from_this_person_to_poi                    NaN                NaN
# loan_advances                              NaN                NaN
# long_term_incentive                        NaN              93750
# other                                       69                874
# poi                                      False              False
# restricted_stock                        145796                NaN
# restricted_stock_deferred               -82782                NaN
# salary                                  239671              80818
# shared_receipt_with_poi                    NaN                NaN
# to_messages                                NaN                NaN
# total_payments                          827696             860136
# total_stock_value                        63014            1599641
#
#                                    BECK SALLY W      BELDEN TIMOTHY N  \
# bonus                                    700000               5249999
# deferral_payments                           NaN               2144013
# deferred_income                             NaN              -2334434
# director_fees                               NaN                   NaN
# email_address              sally.beck@enron.com  tim.belden@enron.com
# exercised_stock_options                     NaN                953136
# expenses                                  37172                 17355
# from_messages                              4343                   484
# from_poi_to_this_person                     144                   228
# from_this_person_to_poi                     386                   108
# loan_advances                               NaN                   NaN
# long_term_incentive                         NaN                   NaN
# other                                       566                210698
# poi                                       False                  True
# restricted_stock                         126027                157569
# restricted_stock_deferred                   NaN                   NaN
# salary                                   231330                213999
# shared_receipt_with_poi                    2639                  5521
# to_messages                                7315                  7991
# total_payments                           969068               5501630
# total_stock_value                        126027               1110705
#
#                           BELFER ROBERT            BERBERIAN DAVID    ...     \
# bonus                               NaN                        NaN    ...
# deferral_payments               -102500                        NaN    ...
# deferred_income                     NaN                        NaN    ...
# director_fees                      3285                        NaN    ...
# email_address                       NaN  david.berberian@enron.com    ...
# exercised_stock_options            3285                    1624396    ...
# expenses                            NaN                      11892    ...
# from_messages                       NaN                        NaN    ...
# from_poi_to_this_person             NaN                        NaN    ...
# from_this_person_to_poi             NaN                        NaN    ...
# loan_advances                       NaN                        NaN    ...
# long_term_incentive                 NaN                        NaN    ...
# other                               NaN                        NaN    ...
# poi                               False                      False    ...
# restricted_stock                    NaN                     869220    ...
# restricted_stock_deferred         44093                        NaN    ...
# salary                              NaN                     216582    ...
# shared_receipt_with_poi             NaN                        NaN    ...
# to_messages                         NaN                        NaN    ...
# total_payments                   102500                     228474    ...
# total_stock_value                -44093                    2493616    ...
#
#                                      WASAFF GEORGE       WESTFAHL RICHARD K  \
# bonus                                       325000                      NaN
# deferral_payments                           831299                      NaN
# deferred_income                            -583325                   -10800
# director_fees                                  NaN                      NaN
# email_address              george.wasaff@enron.com  dick.westfahl@enron.com
# exercised_stock_options                    1668260                      NaN
# expenses                                       NaN                    51870
# from_messages                                   30                      NaN
# from_poi_to_this_person                         22                      NaN
# from_this_person_to_poi                          7                      NaN
# loan_advances                                  NaN                      NaN
# long_term_incentive                         200000                   256191
# other                                         1425                   401130
# poi                                          False                    False
# restricted_stock                            388167                   384930
# restricted_stock_deferred                      NaN                      NaN
# salary                                      259996                    63744
# shared_receipt_with_poi                        337                      NaN
# to_messages                                    400                      NaN
# total_payments                             1034395                   762135
# total_stock_value                          2056427                   384930
#
#                           WHALEY DAVID A      WHALLEY LAWRENCE G  \
# bonus                                NaN                 3000000
# deferral_payments                    NaN                     NaN
# deferred_income                      NaN                     NaN
# director_fees                        NaN                     NaN
# email_address                        NaN  greg.whalley@enron.com
# exercised_stock_options            98718                 3282960
# expenses                             NaN                   57838
# from_messages                        NaN                     556
# from_poi_to_this_person              NaN                     186
# from_this_person_to_poi              NaN                      24
# loan_advances                        NaN                     NaN
# long_term_incentive                  NaN                  808346
# other                                NaN                  301026
# poi                                False                   False
# restricted_stock                     NaN                 2796177
# restricted_stock_deferred            NaN                     NaN
# salary                               NaN                  510364
# shared_receipt_with_poi              NaN                    3920
# to_messages                          NaN                    6019
# total_payments                       NaN                 4677574
# total_stock_value                  98718                 6079137
#
#                                 WHITE JR THOMAS E WINOKUR JR. HERBERT S  \
# bonus                                      450000                   NaN
# deferral_payments                             NaN                   NaN
# deferred_income                               NaN                -25000
# director_fees                                 NaN                108579
# email_address              thomas.white@enron.com                   NaN
# exercised_stock_options                   1297049                   NaN
# expenses                                    81353                  1413
# from_messages                                 NaN                   NaN
# from_poi_to_this_person                       NaN                   NaN
# from_this_person_to_poi                       NaN                   NaN
# loan_advances                                 NaN                   NaN
# long_term_incentive                           NaN                   NaN
# other                                     1085463                   NaN
# poi                                         False                 False
# restricted_stock                         13847074                   NaN
# restricted_stock_deferred                     NaN                   NaN
# salary                                     317543                   NaN
# shared_receipt_with_poi                       NaN                   NaN
# to_messages                                   NaN                   NaN
# total_payments                            1934359                 84992
# total_stock_value                        15144123                   NaN
#
#                                      WODRASKA JOHN WROBEL BRUCE  \
# bonus                                          NaN          NaN
# deferral_payments                              NaN          NaN
# deferred_income                                NaN          NaN
# director_fees                                  NaN          NaN
# email_address              john.wodraska@enron.com          NaN
# exercised_stock_options                        NaN       139130
# expenses                                       NaN          NaN
# from_messages                                  NaN          NaN
# from_poi_to_this_person                        NaN          NaN
# from_this_person_to_poi                        NaN          NaN
# loan_advances                                  NaN          NaN
# long_term_incentive                            NaN          NaN
# other                                       189583          NaN
# poi                                          False        False
# restricted_stock                               NaN          NaN
# restricted_stock_deferred                      NaN          NaN
# salary                                         NaN          NaN
# shared_receipt_with_poi                        NaN          NaN
# to_messages                                    NaN          NaN
# total_payments                              189583          NaN
# total_stock_value                              NaN       139130
#
#                                    YEAGER F SCOTT YEAP SOON
# bonus                                         NaN       NaN
# deferral_payments                             NaN       NaN
# deferred_income                               NaN       NaN
# director_fees                                 NaN       NaN
# email_address              scott.yeager@enron.com       NaN
# exercised_stock_options                   8308552    192758
# expenses                                    53947     55097
# from_messages                                 NaN       NaN
# from_poi_to_this_person                       NaN       NaN
# from_this_person_to_poi                       NaN       NaN
# loan_advances                                 NaN       NaN
# long_term_incentive                           NaN       NaN
# other                                      147950       NaN
# poi                                          True     False
# restricted_stock                          3576206       NaN
# restricted_stock_deferred                     NaN       NaN
# salary                                     158403       NaN
# shared_receipt_with_poi                       NaN       NaN
# to_messages                                   NaN       NaN
# total_payments                             360300     55097
# total_stock_value                        11884758    192758
#
# [21 rows x 146 columns]
#                                    ALLEN PHILLIP K BADUM JAMES P  \
# bonus                                      4175000           NaN
# deferral_payments                          2869717        178980
# deferred_income                           -3081055           NaN
# director_fees                                  NaN           NaN
# email_address              phillip.allen@enron.com           NaN
# exercised_stock_options                    1729541        257817
# expenses                                     13868          3486
# from_messages                                 2195           NaN
# from_poi_to_this_person                         47           NaN
# from_this_person_to_poi                         65           NaN
# loan_advances                                  NaN           NaN
# long_term_incentive                         304805           NaN
# other                                          152           NaN
# poi                                          False         False
# restricted_stock                            126027           NaN
# restricted_stock_deferred                  -126027           NaN
# salary                                      201955           NaN
# shared_receipt_with_poi                       1407           NaN
# to_messages                                   2902           NaN
# total_payments                             4484442        182466
# total_stock_value                          1729541        257817
#
#                                    BANNANTINE JAMES M BAXTER JOHN C  \
# bonus                                             NaN       1200000
# deferral_payments                                 NaN       1295738
# deferred_income                                 -5104      -1386055
# director_fees                                     NaN           NaN
# email_address              james.bannantine@enron.com           NaN
# exercised_stock_options                       4046157       6680544
# expenses                                        56301         11200
# from_messages                                      29           NaN
# from_poi_to_this_person                            39           NaN
# from_this_person_to_poi                             0           NaN
# loan_advances                                     NaN           NaN
# long_term_incentive                               NaN       1586055
# other                                          864523       2660303
# poi                                             False         False
# restricted_stock                              1757552       3942714
# restricted_stock_deferred                     -560222           NaN
# salary                                            477        267102
# shared_receipt_with_poi                           465           NaN
# to_messages                                       566           NaN
# total_payments                                 916197       5634343
# total_stock_value                             5243487      10623258
#
#                                 BAY FRANKLIN R BAZELIDES PHILIP J  \
# bonus                                   400000                NaN
# deferral_payments                       260455             684694
# deferred_income                        -201641                NaN
# director_fees                              NaN                NaN
# email_address              frank.bay@enron.com                NaN
# exercised_stock_options                    NaN            1599641
# expenses                                129142                NaN
# from_messages                              NaN                NaN
# from_poi_to_this_person                    NaN                NaN
# from_this_person_to_poi                    NaN                NaN
# loan_advances                              NaN                NaN
# long_term_incentive                        NaN              93750
# other                                       69                874
# poi                                      False              False
# restricted_stock                        145796                NaN
# restricted_stock_deferred               -82782                NaN
# salary                                  239671              80818
# shared_receipt_with_poi                    NaN                NaN
# to_messages                                NaN                NaN
# total_payments                          827696             860136
# total_stock_value                        63014            1599641
#
#                                    BECK SALLY W      BELDEN TIMOTHY N  \
# bonus                                    700000               5249999
# deferral_payments                           NaN               2144013
# deferred_income                             NaN              -2334434
# director_fees                               NaN                   NaN
# email_address              sally.beck@enron.com  tim.belden@enron.com
# exercised_stock_options                     NaN                953136
# expenses                                  37172                 17355
# from_messages                              4343                   484
# from_poi_to_this_person                     144                   228
# from_this_person_to_poi                     386                   108
# loan_advances                               NaN                   NaN
# long_term_incentive                         NaN                   NaN
# other                                       566                210698
# poi                                       False                  True
# restricted_stock                         126027                157569
# restricted_stock_deferred                   NaN                   NaN
# salary                                   231330                213999
# shared_receipt_with_poi                    2639                  5521
# to_messages                                7315                  7991
# total_payments                           969068               5501630
# total_stock_value                        126027               1110705
#
#                           BELFER ROBERT            BERBERIAN DAVID    ...     \
# bonus                               NaN                        NaN    ...
# deferral_payments               -102500                        NaN    ...
# deferred_income                     NaN                        NaN    ...
# director_fees                      3285                        NaN    ...
# email_address                       NaN  david.berberian@enron.com    ...
# exercised_stock_options            3285                    1624396    ...
# expenses                            NaN                      11892    ...
# from_messages                       NaN                        NaN    ...
# from_poi_to_this_person             NaN                        NaN    ...
# from_this_person_to_poi             NaN                        NaN    ...
# loan_advances                       NaN                        NaN    ...
# long_term_incentive                 NaN                        NaN    ...
# other                               NaN                        NaN    ...
# poi                               False                      False    ...
# restricted_stock                    NaN                     869220    ...
# restricted_stock_deferred         44093                        NaN    ...
# salary                              NaN                     216582    ...
# shared_receipt_with_poi             NaN                        NaN    ...
# to_messages                         NaN                        NaN    ...
# total_payments                   102500                     228474    ...
# total_stock_value                -44093                    2493616    ...
#
#                                      WASAFF GEORGE       WESTFAHL RICHARD K  \
# bonus                                       325000                      NaN
# deferral_payments                           831299                      NaN
# deferred_income                            -583325                   -10800
# director_fees                                  NaN                      NaN
# email_address              george.wasaff@enron.com  dick.westfahl@enron.com
# exercised_stock_options                    1668260                      NaN
# expenses                                       NaN                    51870
# from_messages                                   30                      NaN
# from_poi_to_this_person                         22                      NaN
# from_this_person_to_poi                          7                      NaN
# loan_advances                                  NaN                      NaN
# long_term_incentive                         200000                   256191
# other                                         1425                   401130
# poi                                          False                    False
# restricted_stock                            388167                   384930
# restricted_stock_deferred                      NaN                      NaN
# salary                                      259996                    63744
# shared_receipt_with_poi                        337                      NaN
# to_messages                                    400                      NaN
# total_payments                             1034395                   762135
# total_stock_value                          2056427                   384930
#
#                           WHALEY DAVID A      WHALLEY LAWRENCE G  \
# bonus                                NaN                 3000000
# deferral_payments                    NaN                     NaN
# deferred_income                      NaN                     NaN
# director_fees                        NaN                     NaN
# email_address                        NaN  greg.whalley@enron.com
# exercised_stock_options            98718                 3282960
# expenses                             NaN                   57838
# from_messages                        NaN                     556
# from_poi_to_this_person              NaN                     186
# from_this_person_to_poi              NaN                      24
# loan_advances                        NaN                     NaN
# long_term_incentive                  NaN                  808346
# other                                NaN                  301026
# poi                                False                   False
# restricted_stock                     NaN                 2796177
# restricted_stock_deferred            NaN                     NaN
# salary                               NaN                  510364
# shared_receipt_with_poi              NaN                    3920
# to_messages                          NaN                    6019
# total_payments                       NaN                 4677574
# total_stock_value                  98718                 6079137
#
#                                 WHITE JR THOMAS E WINOKUR JR. HERBERT S  \
# bonus                                      450000                   NaN
# deferral_payments                             NaN                   NaN
# deferred_income                               NaN                -25000
# director_fees                                 NaN                108579
# email_address              thomas.white@enron.com                   NaN
# exercised_stock_options                   1297049                   NaN
# expenses                                    81353                  1413
# from_messages                                 NaN                   NaN
# from_poi_to_this_person                       NaN                   NaN
# from_this_person_to_poi                       NaN                   NaN
# loan_advances                                 NaN                   NaN
# long_term_incentive                           NaN                   NaN
# other                                     1085463                   NaN
# poi                                         False                 False
# restricted_stock                         13847074                   NaN
# restricted_stock_deferred                     NaN                   NaN
# salary                                     317543                   NaN
# shared_receipt_with_poi                       NaN                   NaN
# to_messages                                   NaN                   NaN
# total_payments                            1934359                 84992
# total_stock_value                        15144123                   NaN
#
#                                      WODRASKA JOHN WROBEL BRUCE  \
# bonus                                          NaN          NaN
# deferral_payments                              NaN          NaN
# deferred_income                                NaN          NaN
# director_fees                                  NaN          NaN
# email_address              john.wodraska@enron.com          NaN
# exercised_stock_options                        NaN       139130
# expenses                                       NaN          NaN
# from_messages                                  NaN          NaN
# from_poi_to_this_person                        NaN          NaN
# from_this_person_to_poi                        NaN          NaN
# loan_advances                                  NaN          NaN
# long_term_incentive                            NaN          NaN
# other                                       189583          NaN
# poi                                          False        False
# restricted_stock                               NaN          NaN
# restricted_stock_deferred                      NaN          NaN
# salary                                         NaN          NaN
# shared_receipt_with_poi                        NaN          NaN
# to_messages                                    NaN          NaN
# total_payments                              189583          NaN
# total_stock_value                              NaN       139130
#
#                                    YEAGER F SCOTT YEAP SOON
# bonus                                         NaN       NaN
# deferral_payments                             NaN       NaN
# deferred_income                               NaN       NaN
# director_fees                                 NaN       NaN
# email_address              scott.yeager@enron.com       NaN
# exercised_stock_options                   8308552    192758
# expenses                                    53947     55097
# from_messages                                 NaN       NaN
# from_poi_to_this_person                       NaN       NaN
# from_this_person_to_poi                       NaN       NaN
# loan_advances                                 NaN       NaN
# long_term_incentive                           NaN       NaN
# other                                      147950       NaN
# poi                                          True     False
# restricted_stock                          3576206       NaN
# restricted_stock_deferred                     NaN       NaN
# salary                                     158403       NaN
# shared_receipt_with_poi                       NaN       NaN
# to_messages                                   NaN       NaN
# total_payments                             360300     55097
# total_stock_value                        11884758    192758
#
# [21 rows x 146 columns]

# %% [markdown]
# ## Stacking, unstacking, and rearranging
#
# The data is not formatted in the proper manner. The variables (features) should be in the columns and the unique instances should be in the rows.
#
# The following functions can be used to resolve this issue.
#
# - [`pandas.DataFrame.stack()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html)
# - [`pandas.DataFrame.unstack()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html)
#
# First, we need to `stack` the current column indices, moving them to the innermost level of the row index.
#
# **Run** the cell below to see the results of calling `enron_df.stack()`

# %%
enron_df.stack()
# Out:
# bonus              ALLEN PHILLIP K                    4175000
#                    BADUM JAMES P                          NaN
#                    BANNANTINE JAMES M                     NaN
#                    BAXTER JOHN C                      1200000
#                    BAY FRANKLIN R                      400000
#                    BAZELIDES PHILIP J                     NaN
#                    BECK SALLY W                        700000
#                    BELDEN TIMOTHY N                   5249999
#                    BELFER ROBERT                          NaN
#                    BERBERIAN DAVID                        NaN
#                    BERGSIEKER RICHARD P                250000
#                    BHATNAGAR SANJAY                       NaN
#                    BIBI PHILIPPE A                    1000000
#                    BLACHMAN JEREMY M                   850000
#                    BLAKE JR. NORMAN P                     NaN
#                    BOWEN JR RAYMOND M                 1350000
#                    BROWN MICHAEL                          NaN
#                    BUCHANAN HAROLD G                   500000
#                    BUTTS ROBERT H                      750000
#                    BUY RICHARD B                       900000
#                    CALGER CHRISTOPHER F               1250000
#                    CARTER REBECCA C                    300000
#                    CAUSEY RICHARD A                   1000000
#                    CHAN RONNIE                            NaN
#                    CHRISTODOULOU DIOMEDES                 NaN
#                    CLINE KENNETH W                        NaN
#                    COLWELL WESLEY                     1200000
#                    CORDES WILLIAM R                       NaN
#                    COX DAVID                           800000
#                    CUMBERLAND MICHAEL S                325000
#                    DEFFNER JOSEPH M                    600000
#                    DELAINEY DAVID W                   3000000
#                    DERRICK JR. JAMES V                 800000
#                    DETMERING TIMOTHY J                 425000
#                    DIETRICH JANET R                    600000
#                    DIMICHELE RICHARD G                1000000
#                    DODSON KEITH                         70000
#                    DONAHUE JR JEFFREY M                800000
#                    DUNCAN JOHN H                          NaN
#                    DURAN WILLIAM D                     750000
#                    ECHOLS JOHN B                       200000
#                    ELLIOTT STEVEN                      350000
#                    FALLON JAMES B                     2500000
#                    FASTOW ANDREW S                    1300000
#                    FITZGERALD JAY L                    350000
#                    FOWLER PEGGY                           NaN
#                    FOY JOE                                NaN
#                    FREVERT MARK A                     2000000
#                    FUGH JOHN L                            NaN
#                    GAHN ROBERT S                       509870
#                                                       ...
# total_stock_value  MORAN MICHAEL P                     221141
#                    MORDAUNT KRISTINA M                 208510
#                    MULLER MARK S                      1416848
#                    MURRAY JULIA H                      597461
#                    NOLES JAMES L                       368705
#                    OLSON CINDY K                      2606763
#                    OVERDYKE JR JERE C                 7307594
#                    PAI LOU L                         23817930
#                    PEREIRA PAULO V. FERRAZ                NaN
#                    PICKERING MARK R                     28798
#                    PIPER GREGORY F                     880290
#                    PIRO JIM                             47304
#                    POWERS WILLIAM                         NaN
#                    PRENTICE JAMES                     1095040
#                    REDMOND BRIAN L                    7890324
#                    REYNOLDS LAWRENCE                  4221891
#                    RICE KENNETH D                    22542539
#                    RIEKER PAULA H                     1918887
#                    SAVAGE FRANK                           NaN
#                    SCRIMSHAW MATTHEW                   759557
#                    SHANKMAN JEFFREY A                 2072035
#                    SHAPIRO RICHARD S                   987001
#                    SHARP VICTORIA T                    494136
#                    SHELBY REX                         2493616
#                    SHERRICK JEFFREY B                 1832468
#                    SHERRIFF JOHN R                    3128982
#                    SKILLING JEFFREY K                26093672
#                    STABLER FRANK                       511734
#                    SULLIVAN-SHAKLOVITZ COLLEEN        1362375
#                    SUNDE MARTIN                        698920
#                    TAYLOR MITCHELL S                  3745048
#                    THE TRAVEL AGENCY IN THE PARK          NaN
#                    THORN TERENCE H                    4817796
#                    TILNEY ELIZABETH A                 1168042
#                    TOTAL                            434509511
#                    UMANOFF ADAM S                         NaN
#                    URQUHART JOHN A                        NaN
#                    WAKEHAM JOHN                           NaN
#                    WALLS JR ROBERT H                  5898997
#                    WALTERS GARETH W                   1030329
#                    WASAFF GEORGE                      2056427
#                    WESTFAHL RICHARD K                  384930
#                    WHALEY DAVID A                       98718
#                    WHALLEY LAWRENCE G                 6079137
#                    WHITE JR THOMAS E                 15144123
#                    WINOKUR JR. HERBERT S                  NaN
#                    WODRASKA JOHN                          NaN
#                    WROBEL BRUCE                        139130
#                    YEAGER F SCOTT                    11884758
#                    YEAP SOON                           192758
# dtype: object

# %% [markdown]
# We see that the result of `enron_df.stack()` is a `Series` object, where the innermost (rightmost) level of the index is the person's name in the Enron data set, while the outermost (leftmost) level of the index is the feature. If we call `unstack()` on the resulting `series` without specifying a level, we'll just revert to the original `DataFrame`.
#
# **Run** the cell below to see the result of calling `enron_df.stack().unstack()`

# %%
enron_df.stack().unstack()
# Out:
#                                    ALLEN PHILLIP K BADUM JAMES P  \
# bonus                                      4175000           NaN
# deferral_payments                          2869717        178980
# deferred_income                           -3081055           NaN
# director_fees                                  NaN           NaN
# email_address              phillip.allen@enron.com           NaN
# exercised_stock_options                    1729541        257817
# expenses                                     13868          3486
# from_messages                                 2195           NaN
# from_poi_to_this_person                         47           NaN
# from_this_person_to_poi                         65           NaN
# loan_advances                                  NaN           NaN
# long_term_incentive                         304805           NaN
# other                                          152           NaN
# poi                                          False         False
# restricted_stock                            126027           NaN
# restricted_stock_deferred                  -126027           NaN
# salary                                      201955           NaN
# shared_receipt_with_poi                       1407           NaN
# to_messages                                   2902           NaN
# total_payments                             4484442        182466
# total_stock_value                          1729541        257817
#
#                                    BANNANTINE JAMES M BAXTER JOHN C  \
# bonus                                             NaN       1200000
# deferral_payments                                 NaN       1295738
# deferred_income                                 -5104      -1386055
# director_fees                                     NaN           NaN
# email_address              james.bannantine@enron.com           NaN
# exercised_stock_options                       4046157       6680544
# expenses                                        56301         11200
# from_messages                                      29           NaN
# from_poi_to_this_person                            39           NaN
# from_this_person_to_poi                             0           NaN
# loan_advances                                     NaN           NaN
# long_term_incentive                               NaN       1586055
# other                                          864523       2660303
# poi                                             False         False
# restricted_stock                              1757552       3942714
# restricted_stock_deferred                     -560222           NaN
# salary                                            477        267102
# shared_receipt_with_poi                           465           NaN
# to_messages                                       566           NaN
# total_payments                                 916197       5634343
# total_stock_value                             5243487      10623258
#
#                                 BAY FRANKLIN R BAZELIDES PHILIP J  \
# bonus                                   400000                NaN
# deferral_payments                       260455             684694
# deferred_income                        -201641                NaN
# director_fees                              NaN                NaN
# email_address              frank.bay@enron.com                NaN
# exercised_stock_options                    NaN            1599641
# expenses                                129142                NaN
# from_messages                              NaN                NaN
# from_poi_to_this_person                    NaN                NaN
# from_this_person_to_poi                    NaN                NaN
# loan_advances                              NaN                NaN
# long_term_incentive                        NaN              93750
# other                                       69                874
# poi                                      False              False
# restricted_stock                        145796                NaN
# restricted_stock_deferred               -82782                NaN
# salary                                  239671              80818
# shared_receipt_with_poi                    NaN                NaN
# to_messages                                NaN                NaN
# total_payments                          827696             860136
# total_stock_value                        63014            1599641
#
#                                    BECK SALLY W      BELDEN TIMOTHY N  \
# bonus                                    700000               5249999
# deferral_payments                           NaN               2144013
# deferred_income                             NaN              -2334434
# director_fees                               NaN                   NaN
# email_address              sally.beck@enron.com  tim.belden@enron.com
# exercised_stock_options                     NaN                953136
# expenses                                  37172                 17355
# from_messages                              4343                   484
# from_poi_to_this_person                     144                   228
# from_this_person_to_poi                     386                   108
# loan_advances                               NaN                   NaN
# long_term_incentive                         NaN                   NaN
# other                                       566                210698
# poi                                       False                  True
# restricted_stock                         126027                157569
# restricted_stock_deferred                   NaN                   NaN
# salary                                   231330                213999
# shared_receipt_with_poi                    2639                  5521
# to_messages                                7315                  7991
# total_payments                           969068               5501630
# total_stock_value                        126027               1110705
#
#                           BELFER ROBERT            BERBERIAN DAVID    ...     \
# bonus                               NaN                        NaN    ...
# deferral_payments               -102500                        NaN    ...
# deferred_income                     NaN                        NaN    ...
# director_fees                      3285                        NaN    ...
# email_address                       NaN  david.berberian@enron.com    ...
# exercised_stock_options            3285                    1624396    ...
# expenses                            NaN                      11892    ...
# from_messages                       NaN                        NaN    ...
# from_poi_to_this_person             NaN                        NaN    ...
# from_this_person_to_poi             NaN                        NaN    ...
# loan_advances                       NaN                        NaN    ...
# long_term_incentive                 NaN                        NaN    ...
# other                               NaN                        NaN    ...
# poi                               False                      False    ...
# restricted_stock                    NaN                     869220    ...
# restricted_stock_deferred         44093                        NaN    ...
# salary                              NaN                     216582    ...
# shared_receipt_with_poi             NaN                        NaN    ...
# to_messages                         NaN                        NaN    ...
# total_payments                   102500                     228474    ...
# total_stock_value                -44093                    2493616    ...
#
#                                      WASAFF GEORGE       WESTFAHL RICHARD K  \
# bonus                                       325000                      NaN
# deferral_payments                           831299                      NaN
# deferred_income                            -583325                   -10800
# director_fees                                  NaN                      NaN
# email_address              george.wasaff@enron.com  dick.westfahl@enron.com
# exercised_stock_options                    1668260                      NaN
# expenses                                       NaN                    51870
# from_messages                                   30                      NaN
# from_poi_to_this_person                         22                      NaN
# from_this_person_to_poi                          7                      NaN
# loan_advances                                  NaN                      NaN
# long_term_incentive                         200000                   256191
# other                                         1425                   401130
# poi                                          False                    False
# restricted_stock                            388167                   384930
# restricted_stock_deferred                      NaN                      NaN
# salary                                      259996                    63744
# shared_receipt_with_poi                        337                      NaN
# to_messages                                    400                      NaN
# total_payments                             1034395                   762135
# total_stock_value                          2056427                   384930
#
#                           WHALEY DAVID A      WHALLEY LAWRENCE G  \
# bonus                                NaN                 3000000
# deferral_payments                    NaN                     NaN
# deferred_income                      NaN                     NaN
# director_fees                        NaN                     NaN
# email_address                        NaN  greg.whalley@enron.com
# exercised_stock_options            98718                 3282960
# expenses                             NaN                   57838
# from_messages                        NaN                     556
# from_poi_to_this_person              NaN                     186
# from_this_person_to_poi              NaN                      24
# loan_advances                        NaN                     NaN
# long_term_incentive                  NaN                  808346
# other                                NaN                  301026
# poi                                False                   False
# restricted_stock                     NaN                 2796177
# restricted_stock_deferred            NaN                     NaN
# salary                               NaN                  510364
# shared_receipt_with_poi              NaN                    3920
# to_messages                          NaN                    6019
# total_payments                       NaN                 4677574
# total_stock_value                  98718                 6079137
#
#                                 WHITE JR THOMAS E WINOKUR JR. HERBERT S  \
# bonus                                      450000                   NaN
# deferral_payments                             NaN                   NaN
# deferred_income                               NaN                -25000
# director_fees                                 NaN                108579
# email_address              thomas.white@enron.com                   NaN
# exercised_stock_options                   1297049                   NaN
# expenses                                    81353                  1413
# from_messages                                 NaN                   NaN
# from_poi_to_this_person                       NaN                   NaN
# from_this_person_to_poi                       NaN                   NaN
# loan_advances                                 NaN                   NaN
# long_term_incentive                           NaN                   NaN
# other                                     1085463                   NaN
# poi                                         False                 False
# restricted_stock                         13847074                   NaN
# restricted_stock_deferred                     NaN                   NaN
# salary                                     317543                   NaN
# shared_receipt_with_poi                       NaN                   NaN
# to_messages                                   NaN                   NaN
# total_payments                            1934359                 84992
# total_stock_value                        15144123                   NaN
#
#                                      WODRASKA JOHN WROBEL BRUCE  \
# bonus                                          NaN          NaN
# deferral_payments                              NaN          NaN
# deferred_income                                NaN          NaN
# director_fees                                  NaN          NaN
# email_address              john.wodraska@enron.com          NaN
# exercised_stock_options                        NaN       139130
# expenses                                       NaN          NaN
# from_messages                                  NaN          NaN
# from_poi_to_this_person                        NaN          NaN
# from_this_person_to_poi                        NaN          NaN
# loan_advances                                  NaN          NaN
# long_term_incentive                            NaN          NaN
# other                                       189583          NaN
# poi                                          False        False
# restricted_stock                               NaN          NaN
# restricted_stock_deferred                      NaN          NaN
# salary                                         NaN          NaN
# shared_receipt_with_poi                        NaN          NaN
# to_messages                                    NaN          NaN
# total_payments                              189583          NaN
# total_stock_value                              NaN       139130
#
#                                    YEAGER F SCOTT YEAP SOON
# bonus                                         NaN       NaN
# deferral_payments                             NaN       NaN
# deferred_income                               NaN       NaN
# director_fees                                 NaN       NaN
# email_address              scott.yeager@enron.com       NaN
# exercised_stock_options                   8308552    192758
# expenses                                    53947     55097
# from_messages                                 NaN       NaN
# from_poi_to_this_person                       NaN       NaN
# from_this_person_to_poi                       NaN       NaN
# loan_advances                                 NaN       NaN
# long_term_incentive                           NaN       NaN
# other                                      147950       NaN
# poi                                          True     False
# restricted_stock                          3576206       NaN
# restricted_stock_deferred                     NaN       NaN
# salary                                     158403       NaN
# shared_receipt_with_poi                       NaN       NaN
# to_messages                                   NaN       NaN
# total_payments                             360300     55097
# total_stock_value                        11884758    192758
#
# [21 rows x 146 columns]

# %% [markdown]
# We need to `unstack` the *outermost* level of the index, but by default, the function will `unstack` the *innermost* level of the index.
#
# **Run** the cell below *once* to correctly `stack` and `unstack` the Enron `DataFrame` to move the instances (names) to rows and features (variables) to columns.

# %%
enron_df = enron_df.stack().unstack(0)
display(enron_df)
# Out:
#                                   bonus deferral_payments deferred_income  \
# ALLEN PHILLIP K                 4175000           2869717        -3081055
# BADUM JAMES P                       NaN            178980             NaN
# BANNANTINE JAMES M                  NaN               NaN           -5104
# BAXTER JOHN C                   1200000           1295738        -1386055
# BAY FRANKLIN R                   400000            260455         -201641
# BAZELIDES PHILIP J                  NaN            684694             NaN
# BECK SALLY W                     700000               NaN             NaN
# BELDEN TIMOTHY N                5249999           2144013        -2334434
# BELFER ROBERT                       NaN           -102500             NaN
# BERBERIAN DAVID                     NaN               NaN             NaN
# BERGSIEKER RICHARD P             250000               NaN         -485813
# BHATNAGAR SANJAY                    NaN               NaN             NaN
# BIBI PHILIPPE A                 1000000               NaN             NaN
# BLACHMAN JEREMY M                850000               NaN             NaN
# BLAKE JR. NORMAN P                  NaN               NaN         -113784
# BOWEN JR RAYMOND M              1350000               NaN            -833
# BROWN MICHAEL                       NaN               NaN             NaN
# BUCHANAN HAROLD G                500000               NaN             NaN
# BUTTS ROBERT H                   750000               NaN          -75000
# BUY RICHARD B                    900000            649584         -694862
# CALGER CHRISTOPHER F            1250000               NaN         -262500
# CARTER REBECCA C                 300000               NaN         -159792
# CAUSEY RICHARD A                1000000               NaN         -235000
# CHAN RONNIE                         NaN               NaN          -98784
# CHRISTODOULOU DIOMEDES              NaN               NaN             NaN
# CLINE KENNETH W                     NaN               NaN             NaN
# COLWELL WESLEY                  1200000             27610         -144062
# CORDES WILLIAM R                    NaN               NaN             NaN
# COX DAVID                        800000               NaN          -41250
# CUMBERLAND MICHAEL S             325000               NaN             NaN
# DEFFNER JOSEPH M                 600000               NaN             NaN
# DELAINEY DAVID W                3000000               NaN             NaN
# DERRICK JR. JAMES V              800000               NaN        -1284000
# DETMERING TIMOTHY J              425000            875307         -775241
# DIETRICH JANET R                 600000               NaN             NaN
# DIMICHELE RICHARD G             1000000               NaN             NaN
# DODSON KEITH                      70000               NaN             NaN
# DONAHUE JR JEFFREY M             800000               NaN         -300000
# DUNCAN JOHN H                       NaN               NaN          -25000
# DURAN WILLIAM D                  750000               NaN             NaN
# ECHOLS JOHN B                    200000               NaN             NaN
# ELLIOTT STEVEN                   350000               NaN         -400729
# FALLON JAMES B                  2500000               NaN             NaN
# FASTOW ANDREW S                 1300000               NaN        -1386055
# FITZGERALD JAY L                 350000               NaN             NaN
# FOWLER PEGGY                        NaN               NaN             NaN
# FOY JOE                             NaN            181755             NaN
# FREVERT MARK A                  2000000           6426990        -3367011
# FUGH JOHN L                         NaN             50591             NaN
# GAHN ROBERT S                    509870             73122           -1042
# ...                                 ...               ...             ...
# MORAN MICHAEL P                     NaN               NaN             NaN
# MORDAUNT KRISTINA M              325000               NaN             NaN
# MULLER MARK S                   1100000            842924         -719000
# MURRAY JULIA H                   400000               NaN             NaN
# NOLES JAMES L                       NaN            774401             NaN
# OLSON CINDY K                    750000             77716             NaN
# OVERDYKE JR JERE C                  NaN               NaN             NaN
# PAI LOU L                       1000000               NaN             NaN
# PEREIRA PAULO V. FERRAZ             NaN               NaN         -101250
# PICKERING MARK R                 300000               NaN             NaN
# PIPER GREGORY F                  400000           1130036          -33333
# PIRO JIM                            NaN               NaN             NaN
# POWERS WILLIAM                      NaN               NaN          -17500
# PRENTICE JAMES                      NaN            564348             NaN
# REDMOND BRIAN L                     NaN               NaN             NaN
# REYNOLDS LAWRENCE                100000             51365         -200000
# RICE KENNETH D                  1750000               NaN        -3504386
# RIEKER PAULA H                   700000            214678         -100000
# SAVAGE FRANK                        NaN               NaN         -121284
# SCRIMSHAW MATTHEW                   NaN               NaN             NaN
# SHANKMAN JEFFREY A              2000000               NaN             NaN
# SHAPIRO RICHARD S                650000               NaN             NaN
# SHARP VICTORIA T                 600000            187469             NaN
# SHELBY REX                       200000               NaN           -4167
# SHERRICK JEFFREY B                  NaN               NaN             NaN
# SHERRIFF JOHN R                 1500000               NaN             NaN
# SKILLING JEFFREY K              5600000               NaN             NaN
# STABLER FRANK                    500000               NaN             NaN
# SULLIVAN-SHAKLOVITZ COLLEEN      100000            181993             NaN
# SUNDE MARTIN                     700000               NaN             NaN
# TAYLOR MITCHELL S                600000            227449             NaN
# THE TRAVEL AGENCY IN THE PARK       NaN               NaN             NaN
# THORN TERENCE H                     NaN             16586             NaN
# TILNEY ELIZABETH A               300000               NaN         -575000
# TOTAL                          97343619          32083396       -27992891
# UMANOFF ADAM S                   788750               NaN             NaN
# URQUHART JOHN A                     NaN               NaN          -36666
# WAKEHAM JOHN                        NaN               NaN             NaN
# WALLS JR ROBERT H                850000               NaN             NaN
# WALTERS GARETH W                    NaN             53625             NaN
# WASAFF GEORGE                    325000            831299         -583325
# WESTFAHL RICHARD K                  NaN               NaN          -10800
# WHALEY DAVID A                      NaN               NaN             NaN
# WHALLEY LAWRENCE G              3000000               NaN             NaN
# WHITE JR THOMAS E                450000               NaN             NaN
# WINOKUR JR. HERBERT S               NaN               NaN          -25000
# WODRASKA JOHN                       NaN               NaN             NaN
# WROBEL BRUCE                        NaN               NaN             NaN
# YEAGER F SCOTT                      NaN               NaN             NaN
# YEAP SOON                           NaN               NaN             NaN
#
#                               director_fees                     email_address  \
# ALLEN PHILLIP K                         NaN           phillip.allen@enron.com
# BADUM JAMES P                           NaN                               NaN
# BANNANTINE JAMES M                      NaN        james.bannantine@enron.com
# BAXTER JOHN C                           NaN                               NaN
# BAY FRANKLIN R                          NaN               frank.bay@enron.com
# BAZELIDES PHILIP J                      NaN                               NaN
# BECK SALLY W                            NaN              sally.beck@enron.com
# BELDEN TIMOTHY N                        NaN              tim.belden@enron.com
# BELFER ROBERT                          3285                               NaN
# BERBERIAN DAVID                         NaN         david.berberian@enron.com
# BERGSIEKER RICHARD P                    NaN         rick.bergsieker@enron.com
# BHATNAGAR SANJAY                     137864        sanjay.bhatnagar@enron.com
# BIBI PHILIPPE A                         NaN           philippe.bibi@enron.com
# BLACHMAN JEREMY M                       NaN         jeremy.blachman@enron.com
# BLAKE JR. NORMAN P                   113784                               NaN
# BOWEN JR RAYMOND M                      NaN           raymond.bowen@enron.com
# BROWN MICHAEL                           NaN           michael.brown@enron.com
# BUCHANAN HAROLD G                       NaN           john.buchanan@enron.com
# BUTTS ROBERT H                          NaN               bob.butts@enron.com
# BUY RICHARD B                           NaN                rick.buy@enron.com
# CALGER CHRISTOPHER F                    NaN      christopher.calger@enron.com
# CARTER REBECCA C                        NaN          rebecca.carter@enron.com
# CAUSEY RICHARD A                        NaN          richard.causey@enron.com
# CHAN RONNIE                           98784                               NaN
# CHRISTODOULOU DIOMEDES                  NaN  diomedes.christodoulou@enron.com
# CLINE KENNETH W                         NaN                               NaN
# COLWELL WESLEY                          NaN             wes.colwell@enron.com
# CORDES WILLIAM R                        NaN             bill.cordes@enron.com
# COX DAVID                               NaN                chip.cox@enron.com
# CUMBERLAND MICHAEL S                    NaN                               NaN
# DEFFNER JOSEPH M                        NaN          joseph.deffner@enron.com
# DELAINEY DAVID W                        NaN          david.delainey@enron.com
# DERRICK JR. JAMES V                     NaN           james.derrick@enron.com
# DETMERING TIMOTHY J                     NaN       timothy.detmering@enron.com
# DIETRICH JANET R                        NaN          janet.dietrich@enron.com
# DIMICHELE RICHARD G                     NaN       richard.dimichele@enron.com
# DODSON KEITH                            NaN            keith.dodson@enron.com
# DONAHUE JR JEFFREY M                    NaN            jeff.donahue@enron.com
# DUNCAN JOHN H                        102492                               NaN
# DURAN WILLIAM D                         NaN                 w.duran@enron.com
# ECHOLS JOHN B                           NaN             john.echols@enron.com
# ELLIOTT STEVEN                          NaN          steven.elliott@enron.com
# FALLON JAMES B                          NaN              jim.fallon@enron.com
# FASTOW ANDREW S                         NaN           andrew.fastow@enron.com
# FITZGERALD JAY L                        NaN          jay.fitzgerald@enron.com
# FOWLER PEGGY                            NaN        kulvinder.fowler@enron.com
# FOY JOE                                 NaN               tracy.foy@enron.com
# FREVERT MARK A                          NaN            mark.frevert@enron.com
# FUGH JOHN L                             NaN                               NaN
# GAHN ROBERT S                           NaN                               NaN
# ...                                     ...                               ...
# MORAN MICHAEL P                         NaN           michael.moran@enron.com
# MORDAUNT KRISTINA M                     NaN       kristina.mordaunt@enron.com
# MULLER MARK S                           NaN               s..muller@enron.com
# MURRAY JULIA H                          NaN            julia.murray@enron.com
# NOLES JAMES L                           NaN                               NaN
# OLSON CINDY K                           NaN             cindy.olson@enron.com
# OVERDYKE JR JERE C                      NaN           jere.overdyke@enron.com
# PAI LOU L                               NaN                 lou.pai@enron.com
# PEREIRA PAULO V. FERRAZ              101250                               NaN
# PICKERING MARK R                        NaN          mark.pickering@enron.com
# PIPER GREGORY F                         NaN              greg.piper@enron.com
# PIRO JIM                                NaN                jim.piro@enron.com
# POWERS WILLIAM                        17500              ken.powers@enron.com
# PRENTICE JAMES                          NaN          james.prentice@enron.com
# REDMOND BRIAN L                         NaN           brian.redmond@enron.com
# REYNOLDS LAWRENCE                       NaN                               NaN
# RICE KENNETH D                          NaN                ken.rice@enron.com
# RIEKER PAULA H                          NaN            paula.rieker@enron.com
# SAVAGE FRANK                         125034                               NaN
# SCRIMSHAW MATTHEW                       NaN       matthew.scrimshaw@enron.com
# SHANKMAN JEFFREY A                      NaN        jeffrey.shankman@enron.com
# SHAPIRO RICHARD S                       NaN         richard.shapiro@enron.com
# SHARP VICTORIA T                        NaN             vicki.sharp@enron.com
# SHELBY REX                              NaN              rex.shelby@enron.com
# SHERRICK JEFFREY B                      NaN        jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                         NaN           john.sherriff@enron.com
# SKILLING JEFFREY K                      NaN           jeff.skilling@enron.com
# STABLER FRANK                           NaN           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN             NaN                               NaN
# SUNDE MARTIN                            NaN             marty.sunde@enron.com
# TAYLOR MITCHELL S                       NaN         mitchell.taylor@enron.com
# THE TRAVEL AGENCY IN THE PARK           NaN                               NaN
# THORN TERENCE H                         NaN           terence.thorn@enron.com
# TILNEY ELIZABETH A                      NaN        elizabeth.tilney@enron.com
# TOTAL                               1398517                               NaN
# UMANOFF ADAM S                          NaN            adam.umanoff@enron.com
# URQUHART JOHN A                       36666                               NaN
# WAKEHAM JOHN                         109298                               NaN
# WALLS JR ROBERT H                       NaN               rob.walls@enron.com
# WALTERS GARETH W                        NaN                               NaN
# WASAFF GEORGE                           NaN           george.wasaff@enron.com
# WESTFAHL RICHARD K                      NaN           dick.westfahl@enron.com
# WHALEY DAVID A                          NaN                               NaN
# WHALLEY LAWRENCE G                      NaN            greg.whalley@enron.com
# WHITE JR THOMAS E                       NaN            thomas.white@enron.com
# WINOKUR JR. HERBERT S                108579                               NaN
# WODRASKA JOHN                           NaN           john.wodraska@enron.com
# WROBEL BRUCE                            NaN                               NaN
# YEAGER F SCOTT                          NaN            scott.yeager@enron.com
# YEAP SOON                               NaN                               NaN
#
#                               exercised_stock_options expenses from_messages  \
# ALLEN PHILLIP K                               1729541    13868          2195
# BADUM JAMES P                                  257817     3486           NaN
# BANNANTINE JAMES M                            4046157    56301            29
# BAXTER JOHN C                                 6680544    11200           NaN
# BAY FRANKLIN R                                    NaN   129142           NaN
# BAZELIDES PHILIP J                            1599641      NaN           NaN
# BECK SALLY W                                      NaN    37172          4343
# BELDEN TIMOTHY N                               953136    17355           484
# BELFER ROBERT                                    3285      NaN           NaN
# BERBERIAN DAVID                               1624396    11892           NaN
# BERGSIEKER RICHARD P                              NaN    59175            59
# BHATNAGAR SANJAY                              2604490      NaN            29
# BIBI PHILIPPE A                               1465734    38559            40
# BLACHMAN JEREMY M                              765313    84208            14
# BLAKE JR. NORMAN P                                NaN     1279           NaN
# BOWEN JR RAYMOND M                                NaN    65907            27
# BROWN MICHAEL                                     NaN    49288            41
# BUCHANAN HAROLD G                              825464      600           125
# BUTTS ROBERT H                                    NaN     9410           NaN
# BUY RICHARD B                                 2542813      NaN          1053
# CALGER CHRISTOPHER F                              NaN    35818           144
# CARTER REBECCA C                                  NaN      NaN            15
# CAUSEY RICHARD A                                  NaN    30674            49
# CHAN RONNIE                                       NaN      NaN           NaN
# CHRISTODOULOU DIOMEDES                        5127155      NaN           NaN
# CLINE KENNETH W                                   NaN      NaN           NaN
# COLWELL WESLEY                                    NaN    16514            40
# CORDES WILLIAM R                               651850      NaN            12
# COX DAVID                                      117551    27861            33
# CUMBERLAND MICHAEL S                              NaN    22344           NaN
# DEFFNER JOSEPH M                                17378    41626            74
# DELAINEY DAVID W                              2291113    86174          3069
# DERRICK JR. JAMES V                           8831913    51124           909
# DETMERING TIMOTHY J                           2027865    52255           NaN
# DIETRICH JANET R                              1550019     3475            63
# DIMICHELE RICHARD G                           8191755    35812           NaN
# DODSON KEITH                                      NaN    28164            14
# DONAHUE JR JEFFREY M                           765920    96268            22
# DUNCAN JOHN H                                  371750      NaN           NaN
# DURAN WILLIAM D                               1451869    25785            12
# ECHOLS JOHN B                                  601438    21530           NaN
# ELLIOTT STEVEN                                4890344    78552           NaN
# FALLON JAMES B                                 940257    95924            75
# FASTOW ANDREW S                                   NaN    55921           NaN
# FITZGERALD JAY L                               664461    23870            16
# FOWLER PEGGY                                  1324578      NaN            36
# FOY JOE                                        343434      NaN            13
# FREVERT MARK A                               10433518    86987            21
# FUGH JOHN L                                    176378      NaN           NaN
# GAHN ROBERT S                                   83237    50080           NaN
# ...                                               ...      ...           ...
# MORAN MICHAEL P                                 59539      NaN            19
# MORDAUNT KRISTINA M                               NaN    35018           NaN
# MULLER MARK S                                 1056320      NaN            16
# MURRAY JULIA H                                 400478    57580            45
# NOLES JAMES L                                     NaN      NaN           NaN
# OLSON CINDY K                                 1637034    63791            52
# OVERDYKE JR JERE C                            5266578    18834           NaN
# PAI LOU L                                    15364167    32047           NaN
# PEREIRA PAULO V. FERRAZ                           NaN    27942           NaN
# PICKERING MARK R                                28798    31653            67
# PIPER GREGORY F                                880290    43057           222
# PIRO JIM                                          NaN      NaN            16
# POWERS WILLIAM                                    NaN      NaN            26
# PRENTICE JAMES                                 886231      NaN           NaN
# REDMOND BRIAN L                               7509039    14689           221
# REYNOLDS LAWRENCE                             4160672     8409           NaN
# RICE KENNETH D                               19794175    46950            18
# RIEKER PAULA H                                1635238    33271            82
# SAVAGE FRANK                                      NaN      NaN           NaN
# SCRIMSHAW MATTHEW                              759557      NaN           NaN
# SHANKMAN JEFFREY A                            1441898   178979          2681
# SHAPIRO RICHARD S                              607837   137767          1215
# SHARP VICTORIA T                               281073   116337           136
# SHELBY REX                                    1624396    22884            39
# SHERRICK JEFFREY B                            1426469      NaN            25
# SHERRIFF JOHN R                               1835558      NaN            92
# SKILLING JEFFREY K                           19250000    29336           108
# STABLER FRANK                                     NaN    16514           NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                   1362375      NaN           NaN
# SUNDE MARTIN                                      NaN      NaN            38
# TAYLOR MITCHELL S                             3181250      NaN            29
# THE TRAVEL AGENCY IN THE PARK                     NaN      NaN           NaN
# THORN TERENCE H                               4452476    46145            41
# TILNEY ELIZABETH A                             591250      NaN            19
# TOTAL                                       311764000  5235198           NaN
# UMANOFF ADAM S                                    NaN    53122            18
# URQUHART JOHN A                                   NaN   228656           NaN
# WAKEHAM JOHN                                      NaN   103773           NaN
# WALLS JR ROBERT H                             4346544    50936           146
# WALTERS GARETH W                              1030329    33785           NaN
# WASAFF GEORGE                                 1668260      NaN            30
# WESTFAHL RICHARD K                                NaN    51870           NaN
# WHALEY DAVID A                                  98718      NaN           NaN
# WHALLEY LAWRENCE G                            3282960    57838           556
# WHITE JR THOMAS E                             1297049    81353           NaN
# WINOKUR JR. HERBERT S                             NaN     1413           NaN
# WODRASKA JOHN                                     NaN      NaN           NaN
# WROBEL BRUCE                                   139130      NaN           NaN
# YEAGER F SCOTT                                8308552    53947           NaN
# YEAP SOON                                      192758    55097           NaN
#
#                               from_poi_to_this_person from_this_person_to_poi  \
# ALLEN PHILLIP K                                    47                      65
# BADUM JAMES P                                     NaN                     NaN
# BANNANTINE JAMES M                                 39                       0
# BAXTER JOHN C                                     NaN                     NaN
# BAY FRANKLIN R                                    NaN                     NaN
# BAZELIDES PHILIP J                                NaN                     NaN
# BECK SALLY W                                      144                     386
# BELDEN TIMOTHY N                                  228                     108
# BELFER ROBERT                                     NaN                     NaN
# BERBERIAN DAVID                                   NaN                     NaN
# BERGSIEKER RICHARD P                                4                       0
# BHATNAGAR SANJAY                                    0                       1
# BIBI PHILIPPE A                                    23                       8
# BLACHMAN JEREMY M                                  25                       2
# BLAKE JR. NORMAN P                                NaN                     NaN
# BOWEN JR RAYMOND M                                140                      15
# BROWN MICHAEL                                      13                       1
# BUCHANAN HAROLD G                                   0                       0
# BUTTS ROBERT H                                    NaN                     NaN
# BUY RICHARD B                                     156                      71
# CALGER CHRISTOPHER F                              199                      25
# CARTER REBECCA C                                   29                       7
# CAUSEY RICHARD A                                   58                      12
# CHAN RONNIE                                       NaN                     NaN
# CHRISTODOULOU DIOMEDES                            NaN                     NaN
# CLINE KENNETH W                                   NaN                     NaN
# COLWELL WESLEY                                    240                      11
# CORDES WILLIAM R                                   10                       0
# COX DAVID                                           0                       4
# CUMBERLAND MICHAEL S                              NaN                     NaN
# DEFFNER JOSEPH M                                  115                       4
# DELAINEY DAVID W                                   66                     609
# DERRICK JR. JAMES V                                64                      20
# DETMERING TIMOTHY J                               NaN                     NaN
# DIETRICH JANET R                                  305                      14
# DIMICHELE RICHARD G                               NaN                     NaN
# DODSON KEITH                                       10                       3
# DONAHUE JR JEFFREY M                              188                      11
# DUNCAN JOHN H                                     NaN                     NaN
# DURAN WILLIAM D                                   106                       3
# ECHOLS JOHN B                                     NaN                     NaN
# ELLIOTT STEVEN                                    NaN                     NaN
# FALLON JAMES B                                     42                      37
# FASTOW ANDREW S                                   NaN                     NaN
# FITZGERALD JAY L                                    1                       8
# FOWLER PEGGY                                        0                       0
# FOY JOE                                             0                       0
# FREVERT MARK A                                    242                       6
# FUGH JOHN L                                       NaN                     NaN
# GAHN ROBERT S                                     NaN                     NaN
# ...                                               ...                     ...
# MORAN MICHAEL P                                     0                       0
# MORDAUNT KRISTINA M                               NaN                     NaN
# MULLER MARK S                                      12                       0
# MURRAY JULIA H                                     11                       2
# NOLES JAMES L                                     NaN                     NaN
# OLSON CINDY K                                      20                      15
# OVERDYKE JR JERE C                                NaN                     NaN
# PAI LOU L                                         NaN                     NaN
# PEREIRA PAULO V. FERRAZ                           NaN                     NaN
# PICKERING MARK R                                    7                       0
# PIPER GREGORY F                                    61                      48
# PIRO JIM                                            0                       1
# POWERS WILLIAM                                      0                       0
# PRENTICE JAMES                                    NaN                     NaN
# REDMOND BRIAN L                                   204                      49
# REYNOLDS LAWRENCE                                 NaN                     NaN
# RICE KENNETH D                                     42                       4
# RIEKER PAULA H                                     35                      48
# SAVAGE FRANK                                      NaN                     NaN
# SCRIMSHAW MATTHEW                                 NaN                     NaN
# SHANKMAN JEFFREY A                                 94                      83
# SHAPIRO RICHARD S                                  74                      65
# SHARP VICTORIA T                                   24                       6
# SHELBY REX                                         13                      14
# SHERRICK JEFFREY B                                 39                      18
# SHERRIFF JOHN R                                    28                      23
# SKILLING JEFFREY K                                 88                      30
# STABLER FRANK                                     NaN                     NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                       NaN                     NaN
# SUNDE MARTIN                                       37                      13
# TAYLOR MITCHELL S                                   0                       0
# THE TRAVEL AGENCY IN THE PARK                     NaN                     NaN
# THORN TERENCE H                                     0                       0
# TILNEY ELIZABETH A                                 10                      11
# TOTAL                                             NaN                     NaN
# UMANOFF ADAM S                                     12                       0
# URQUHART JOHN A                                   NaN                     NaN
# WAKEHAM JOHN                                      NaN                     NaN
# WALLS JR ROBERT H                                  17                       0
# WALTERS GARETH W                                  NaN                     NaN
# WASAFF GEORGE                                      22                       7
# WESTFAHL RICHARD K                                NaN                     NaN
# WHALEY DAVID A                                    NaN                     NaN
# WHALLEY LAWRENCE G                                186                      24
# WHITE JR THOMAS E                                 NaN                     NaN
# WINOKUR JR. HERBERT S                             NaN                     NaN
# WODRASKA JOHN                                     NaN                     NaN
# WROBEL BRUCE                                      NaN                     NaN
# YEAGER F SCOTT                                    NaN                     NaN
# YEAP SOON                                         NaN                     NaN
#
#                                      ...        long_term_incentive     other  \
# ALLEN PHILLIP K                      ...                     304805       152
# BADUM JAMES P                        ...                        NaN       NaN
# BANNANTINE JAMES M                   ...                        NaN    864523
# BAXTER JOHN C                        ...                    1586055   2660303
# BAY FRANKLIN R                       ...                        NaN        69
# BAZELIDES PHILIP J                   ...                      93750       874
# BECK SALLY W                         ...                        NaN       566
# BELDEN TIMOTHY N                     ...                        NaN    210698
# BELFER ROBERT                        ...                        NaN       NaN
# BERBERIAN DAVID                      ...                        NaN       NaN
# BERGSIEKER RICHARD P                 ...                     180250    427316
# BHATNAGAR SANJAY                     ...                        NaN    137864
# BIBI PHILIPPE A                      ...                     369721    425688
# BLACHMAN JEREMY M                    ...                     831809       272
# BLAKE JR. NORMAN P                   ...                        NaN       NaN
# BOWEN JR RAYMOND M                   ...                     974293      1621
# BROWN MICHAEL                        ...                        NaN       NaN
# BUCHANAN HAROLD G                    ...                     304805      1215
# BUTTS ROBERT H                       ...                     175000    150656
# BUY RICHARD B                        ...                     769862    400572
# CALGER CHRISTOPHER F                 ...                     375304       486
# CARTER REBECCA C                     ...                      75000       540
# CAUSEY RICHARD A                     ...                     350000    307895
# CHAN RONNIE                          ...                        NaN       NaN
# CHRISTODOULOU DIOMEDES               ...                        NaN       NaN
# CLINE KENNETH W                      ...                        NaN       NaN
# COLWELL WESLEY                       ...                        NaN    101740
# CORDES WILLIAM R                     ...                        NaN       NaN
# COX DAVID                            ...                        NaN       494
# CUMBERLAND MICHAEL S                 ...                     275000       713
# DEFFNER JOSEPH M                     ...                     335349     25553
# DELAINEY DAVID W                     ...                    1294981      1661
# DERRICK JR. JAMES V                  ...                     484000      7482
# DETMERING TIMOTHY J                  ...                     415657      1105
# DIETRICH JANET R                     ...                     556416       473
# DIMICHELE RICHARD G                  ...                     694862    374689
# DODSON KEITH                         ...                        NaN       774
# DONAHUE JR JEFFREY M                 ...                        NaN       891
# DUNCAN JOHN H                        ...                        NaN       NaN
# DURAN WILLIAM D                      ...                    1105218      1568
# ECHOLS JOHN B                        ...                    2234774     53775
# ELLIOTT STEVEN                       ...                        NaN     12961
# FALLON JAMES B                       ...                     374347    401481
# FASTOW ANDREW S                      ...                    1736055    277464
# FITZGERALD JAY L                     ...                     556416    285414
# FOWLER PEGGY                         ...                        NaN       NaN
# FOY JOE                              ...                        NaN       NaN
# FREVERT MARK A                       ...                    1617011   7427621
# FUGH JOHN L                          ...                        NaN       NaN
# GAHN ROBERT S                        ...                        NaN     76547
# ...                                  ...                        ...       ...
# MORAN MICHAEL P                      ...                        NaN       NaN
# MORDAUNT KRISTINA M                  ...                        NaN      1411
# MULLER MARK S                        ...                    1725545       947
# MURRAY JULIA H                       ...                     125000       330
# NOLES JAMES L                        ...                        NaN       NaN
# OLSON CINDY K                        ...                     100000       972
# OVERDYKE JR JERE C                   ...                     135836       176
# PAI LOU L                            ...                        NaN   1829457
# PEREIRA PAULO V. FERRAZ              ...                        NaN       NaN
# PICKERING MARK R                     ...                        NaN       NaN
# PIPER GREGORY F                      ...                        NaN       778
# PIRO JIM                             ...                        NaN       NaN
# POWERS WILLIAM                       ...                        NaN       NaN
# PRENTICE JAMES                       ...                        NaN       NaN
# REDMOND BRIAN L                      ...                        NaN       NaN
# REYNOLDS LAWRENCE                    ...                     156250    202052
# RICE KENNETH D                       ...                    1617011    174839
# RIEKER PAULA H                       ...                        NaN      1950
# SAVAGE FRANK                         ...                        NaN       NaN
# SCRIMSHAW MATTHEW                    ...                        NaN       NaN
# SHANKMAN JEFFREY A                   ...                     554422      1191
# SHAPIRO RICHARD S                    ...                        NaN       705
# SHARP VICTORIA T                     ...                     422158      2401
# SHELBY REX                           ...                        NaN   1573324
# SHERRICK JEFFREY B                   ...                        NaN       NaN
# SHERRIFF JOHN R                      ...                     554422   1852186
# SKILLING JEFFREY K                   ...                    1920000     22122
# STABLER FRANK                        ...                        NaN    356071
# SULLIVAN-SHAKLOVITZ COLLEEN          ...                     554422       162
# SUNDE MARTIN                         ...                     476451    111122
# TAYLOR MITCHELL S                    ...                        NaN       NaN
# THE TRAVEL AGENCY IN THE PARK        ...                        NaN    362096
# THORN TERENCE H                      ...                     200000    426629
# TILNEY ELIZABETH A                   ...                     275000    152055
# TOTAL                                ...                   48521928  42667589
# UMANOFF ADAM S                       ...                        NaN       NaN
# URQUHART JOHN A                      ...                        NaN       NaN
# WAKEHAM JOHN                         ...                        NaN       NaN
# WALLS JR ROBERT H                    ...                     540751         2
# WALTERS GARETH W                     ...                        NaN       NaN
# WASAFF GEORGE                        ...                     200000      1425
# WESTFAHL RICHARD K                   ...                     256191    401130
# WHALEY DAVID A                       ...                        NaN       NaN
# WHALLEY LAWRENCE G                   ...                     808346    301026
# WHITE JR THOMAS E                    ...                        NaN   1085463
# WINOKUR JR. HERBERT S                ...                        NaN       NaN
# WODRASKA JOHN                        ...                        NaN    189583
# WROBEL BRUCE                         ...                        NaN       NaN
# YEAGER F SCOTT                       ...                        NaN    147950
# YEAP SOON                            ...                        NaN       NaN
#
#                                  poi restricted_stock  \
# ALLEN PHILLIP K                False           126027
# BADUM JAMES P                  False              NaN
# BANNANTINE JAMES M             False          1757552
# BAXTER JOHN C                  False          3942714
# BAY FRANKLIN R                 False           145796
# BAZELIDES PHILIP J             False              NaN
# BECK SALLY W                   False           126027
# BELDEN TIMOTHY N                True           157569
# BELFER ROBERT                  False              NaN
# BERBERIAN DAVID                False           869220
# BERGSIEKER RICHARD P           False           659249
# BHATNAGAR SANJAY               False         -2604490
# BIBI PHILIPPE A                False           378082
# BLACHMAN JEREMY M              False           189041
# BLAKE JR. NORMAN P             False              NaN
# BOWEN JR RAYMOND M              True           252055
# BROWN MICHAEL                  False              NaN
# BUCHANAN HAROLD G              False           189041
# BUTTS ROBERT H                 False           417619
# BUY RICHARD B                  False           901657
# CALGER CHRISTOPHER F            True           126027
# CARTER REBECCA C               False           307301
# CAUSEY RICHARD A                True          2502063
# CHAN RONNIE                    False            32460
# CHRISTODOULOU DIOMEDES         False           950730
# CLINE KENNETH W                False           662086
# COLWELL WESLEY                  True           698242
# CORDES WILLIAM R               False           386335
# COX DAVID                      False           378082
# CUMBERLAND MICHAEL S           False           207940
# DEFFNER JOSEPH M               False           141833
# DELAINEY DAVID W                True          1323148
# DERRICK JR. JAMES V            False          1787380
# DETMERING TIMOTHY J            False           315068
# DIETRICH JANET R               False           315068
# DIMICHELE RICHARD G            False           126027
# DODSON KEITH                   False              NaN
# DONAHUE JR JEFFREY M           False           315068
# DUNCAN JOHN H                  False              NaN
# DURAN WILLIAM D                False           189041
# ECHOLS JOHN B                  False           407503
# ELLIOTT STEVEN                 False          1788391
# FALLON JAMES B                 False          1392142
# FASTOW ANDREW S                 True          1794412
# FITZGERALD JAY L               False           956775
# FOWLER PEGGY                   False           560170
# FOY JOE                        False              NaN
# FREVERT MARK A                 False          4188667
# FUGH JOHN L                    False              NaN
# GAHN ROBERT S                  False           235370
# ...                              ...              ...
# MORAN MICHAEL P                False           161602
# MORDAUNT KRISTINA M            False           208510
# MULLER MARK S                  False           360528
# MURRAY JULIA H                 False           196983
# NOLES JAMES L                  False           463261
# OLSON CINDY K                  False           969729
# OVERDYKE JR JERE C             False          2041016
# PAI LOU L                      False          8453763
# PEREIRA PAULO V. FERRAZ        False              NaN
# PICKERING MARK R               False              NaN
# PIPER GREGORY F                False           409554
# PIRO JIM                       False            47304
# POWERS WILLIAM                 False              NaN
# PRENTICE JAMES                 False           208809
# REDMOND BRIAN L                False           381285
# REYNOLDS LAWRENCE              False           201483
# RICE KENNETH D                  True          2748364
# RIEKER PAULA H                  True           283649
# SAVAGE FRANK                   False              NaN
# SCRIMSHAW MATTHEW              False              NaN
# SHANKMAN JEFFREY A             False           630137
# SHAPIRO RICHARD S              False           379164
# SHARP VICTORIA T               False           213063
# SHELBY REX                      True           869220
# SHERRICK JEFFREY B             False           405999
# SHERRIFF JOHN R                False          1293424
# SKILLING JEFFREY K              True          6843672
# STABLER FRANK                  False           511734
# SULLIVAN-SHAKLOVITZ COLLEEN    False              NaN
# SUNDE MARTIN                   False           698920
# TAYLOR MITCHELL S              False           563798
# THE TRAVEL AGENCY IN THE PARK  False              NaN
# THORN TERENCE H                False           365320
# TILNEY ELIZABETH A             False           576792
# TOTAL                          False        130322299
# UMANOFF ADAM S                 False              NaN
# URQUHART JOHN A                False              NaN
# WAKEHAM JOHN                   False              NaN
# WALLS JR ROBERT H              False          1552453
# WALTERS GARETH W               False              NaN
# WASAFF GEORGE                  False           388167
# WESTFAHL RICHARD K             False           384930
# WHALEY DAVID A                 False              NaN
# WHALLEY LAWRENCE G             False          2796177
# WHITE JR THOMAS E              False         13847074
# WINOKUR JR. HERBERT S          False              NaN
# WODRASKA JOHN                  False              NaN
# WROBEL BRUCE                   False              NaN
# YEAGER F SCOTT                  True          3576206
# YEAP SOON                      False              NaN
#
#                               restricted_stock_deferred    salary  \
# ALLEN PHILLIP K                                 -126027    201955
# BADUM JAMES P                                       NaN       NaN
# BANNANTINE JAMES M                              -560222       477
# BAXTER JOHN C                                       NaN    267102
# BAY FRANKLIN R                                   -82782    239671
# BAZELIDES PHILIP J                                  NaN     80818
# BECK SALLY W                                        NaN    231330
# BELDEN TIMOTHY N                                    NaN    213999
# BELFER ROBERT                                     44093       NaN
# BERBERIAN DAVID                                     NaN    216582
# BERGSIEKER RICHARD P                                NaN    187922
# BHATNAGAR SANJAY                               15456290       NaN
# BIBI PHILIPPE A                                     NaN    213625
# BLACHMAN JEREMY M                                   NaN    248546
# BLAKE JR. NORMAN P                                  NaN       NaN
# BOWEN JR RAYMOND M                                  NaN    278601
# BROWN MICHAEL                                       NaN       NaN
# BUCHANAN HAROLD G                                   NaN    248017
# BUTTS ROBERT H                                      NaN    261516
# ...
# RIEKER PAULA H                                      NaN    249201
# SAVAGE FRANK                                        NaN       NaN
# SCRIMSHAW MATTHEW                                   NaN       NaN
# SHANKMAN JEFFREY A                                  NaN    304110
# SHAPIRO RICHARD S                                   NaN    269076
# SHARP VICTORIA T                                    NaN    248146
# SHELBY REX                                          NaN    211844
# SHERRICK JEFFREY B                                  NaN       NaN
# SHERRIFF JOHN R                                     NaN    428780
# SKILLING JEFFREY K                                  NaN   1111258
# STABLER FRANK                                       NaN    239502
# SULLIVAN-SHAKLOVITZ COLLEEN                         NaN    162779
# SUNDE MARTIN                                        NaN    257486
# TAYLOR MITCHELL S                                   NaN    265214
# THE TRAVEL AGENCY IN THE PARK                       NaN       NaN
# THORN TERENCE H                                     NaN    222093
# TILNEY ELIZABETH A                                  NaN    247338
# TOTAL                                          -7576788  26704229
# UMANOFF ADAM S                                      NaN    288589
# URQUHART JOHN A                                     NaN       NaN
# WAKEHAM JOHN                                        NaN       NaN
# WALLS JR ROBERT H                                   NaN    357091
# WALTERS GARETH W                                    NaN       NaN
# WASAFF GEORGE                                       NaN    259996
# WESTFAHL RICHARD K                                  NaN     63744
# WHALEY DAVID A                                      NaN       NaN
# WHALLEY LAWRENCE G                                  NaN    510364
# WHITE JR THOMAS E                                   NaN    317543
# WINOKUR JR. HERBERT S                               NaN       NaN
# WODRASKA JOHN                                       NaN       NaN
# WROBEL BRUCE                                        NaN       NaN
# YEAGER F SCOTT                                      NaN    158403
# YEAP SOON                                           NaN       NaN
#
#                               shared_receipt_with_poi to_messages  \
# ALLEN PHILLIP K                                  1407        2902
# BADUM JAMES P                                     NaN         NaN
# BANNANTINE JAMES M                                465         566
# BAXTER JOHN C                                     NaN         NaN
# BAY FRANKLIN R                                    NaN         NaN
# BAZELIDES PHILIP J                                NaN         NaN
# BECK SALLY W                                     2639        7315
# BELDEN TIMOTHY N                                 5521        7991
# BELFER ROBERT                                     NaN         NaN
# BERBERIAN DAVID                                   NaN         NaN
# BERGSIEKER RICHARD P                              233         383
# BHATNAGAR SANJAY                                  463         523
# BIBI PHILIPPE A                                  1336        1607
# BLACHMAN JEREMY M                                2326        2475
# BLAKE JR. NORMAN P                                NaN         NaN
# BOWEN JR RAYMOND M                               1593        1858
# BROWN MICHAEL                                     761        1486
# BUCHANAN HAROLD G                                  23        1088
# BUTTS ROBERT H                                    NaN         NaN
# BUY RICHARD B                                    2333        3523
# CALGER CHRISTOPHER F                             2188        2598
# CARTER REBECCA C                                  196         312
# CAUSEY RICHARD A                                 1585        1892
# CHAN RONNIE                                       NaN         NaN
# CHRISTODOULOU DIOMEDES                            NaN         NaN
# CLINE KENNETH W                                   NaN         NaN
# COLWELL WESLEY                                   1132        1758
# CORDES WILLIAM R                                   58         764
# COX DAVID                                          71         102
# CUMBERLAND MICHAEL S                              NaN         NaN
# DEFFNER JOSEPH M                                  552         714
# DELAINEY DAVID W                                 2097        3093
# DERRICK JR. JAMES V                              1401        2181
# DETMERING TIMOTHY J                               NaN         NaN
# DIETRICH JANET R                                 1902        2572
# DIMICHELE RICHARD G                               NaN         NaN
# DODSON KEITH                                      114         176
# DONAHUE JR JEFFREY M                              772         865
# DUNCAN JOHN H                                     NaN         NaN
# DURAN WILLIAM D                                   599         904
# ECHOLS JOHN B                                     NaN         NaN
# ELLIOTT STEVEN                                    NaN         NaN
# FALLON JAMES B                                   1604        1755
# FASTOW ANDREW S                                   NaN         NaN
# FITZGERALD JAY L                                  723         936
# FOWLER PEGGY                                       10         517
# FOY JOE                                             2          57
# FREVERT MARK A                                   2979        3275
# FUGH JOHN L                                       NaN         NaN
# GAHN ROBERT S                                     NaN         NaN
# ...                                               ...         ...
# MORAN MICHAEL P                                   127         672
# MORDAUNT KRISTINA M                               NaN         NaN
# MULLER MARK S                                     114         136
# MURRAY JULIA H                                    395        2192
# NOLES JAMES L                                     NaN         NaN
# OLSON CINDY K                                     856        1184
# OVERDYKE JR JERE C                                NaN         NaN
# PAI LOU L                                         NaN         NaN
# PEREIRA PAULO V. FERRAZ                           NaN         NaN
# PICKERING MARK R                                  728         898
# PIPER GREGORY F                                   742        1238
# PIRO JIM                                            3          58
# POWERS WILLIAM                                     12         653
# PRENTICE JAMES                                    NaN         NaN
# REDMOND BRIAN L                                  1063        1671
# REYNOLDS LAWRENCE                                 NaN         NaN
# RICE KENNETH D                                    864         905
# RIEKER PAULA H                                   1258        1328
# SAVAGE FRANK                                      NaN         NaN
# SCRIMSHAW MATTHEW                                 NaN         NaN
# SHANKMAN JEFFREY A                               1730        3221
# SHAPIRO RICHARD S                                4527       15149
# SHARP VICTORIA T                                 2477        3136
# SHELBY REX                                         91         225
# SHERRICK JEFFREY B                                583         613
# SHERRIFF JOHN R                                  2103        3187
# SKILLING JEFFREY K                               2042        3627
# STABLER FRANK                                     NaN         NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                       NaN         NaN
# SUNDE MARTIN                                     2565        2647
# TAYLOR MITCHELL S                                 300         533
# THE TRAVEL AGENCY IN THE PARK                     NaN         NaN
# THORN TERENCE H                                    73         266
# TILNEY ELIZABETH A                                379         460
# TOTAL                                             NaN         NaN
# UMANOFF ADAM S                                     41         111
# URQUHART JOHN A                                   NaN         NaN
# WAKEHAM JOHN                                      NaN         NaN
# WALLS JR ROBERT H                                 215         671
# WALTERS GARETH W                                  NaN         NaN
# WASAFF GEORGE                                     337         400
# WESTFAHL RICHARD K                                NaN         NaN
# WHALEY DAVID A                                    NaN         NaN
# WHALLEY LAWRENCE G                               3920        6019
# WHITE JR THOMAS E                                 NaN         NaN
# WINOKUR JR. HERBERT S                             NaN         NaN
# WODRASKA JOHN                                     NaN         NaN
# WROBEL BRUCE                                      NaN         NaN
# YEAGER F SCOTT                                    NaN         NaN
# YEAP SOON                                         NaN         NaN
#
#                               total_payments total_stock_value
# ALLEN PHILLIP K                      4484442           1729541
# BADUM JAMES P                         182466            257817
# BANNANTINE JAMES M                    916197           5243487
# BAXTER JOHN C                        5634343          10623258
# BAY FRANKLIN R                        827696             63014
# BAZELIDES PHILIP J                    860136           1599641
# BECK SALLY W                          969068            126027
# BELDEN TIMOTHY N                     5501630           1110705
# BELFER ROBERT                         102500            -44093
# BERBERIAN DAVID                       228474           2493616
# BERGSIEKER RICHARD P                  618850            659249
# BHATNAGAR SANJAY                    15456290               NaN
# BIBI PHILIPPE A                      2047593           1843816
# BLACHMAN JEREMY M                    2014835            954354
# BLAKE JR. NORMAN P                      1279               NaN
# BOWEN JR RAYMOND M                   2669589            252055
# BROWN MICHAEL                          49288               NaN
# BUCHANAN HAROLD G                    1054637           1014505
# BUTTS ROBERT H                       1271582            417619
# BUY RICHARD B                        2355702           3444470
# CALGER CHRISTOPHER F                 1639297            126027
# CARTER REBECCA C                      477557               NaN
# CAUSEY RICHARD A                     1868758           2502063
# CHAN RONNIE                              NaN               NaN
# CHRISTODOULOU DIOMEDES                   NaN           6077885
# CLINE KENNETH W                          NaN            189518
# COLWELL WESLEY                       1490344            698242
# CORDES WILLIAM R                         NaN           1038185
# COX DAVID                            1101393            495633
# CUMBERLAND MICHAEL S                  807956            207940
# DEFFNER JOSEPH M                     1208649            159211
# DELAINEY DAVID W                     4747979           3614261
# DERRICK JR. JAMES V                   550981           8831913
# DETMERING TIMOTHY J                  1204583           2027865
# DIETRICH JANET R                     1410464           1865087
# DIMICHELE RICHARD G                  2368151           8317782
# DODSON KEITH                          319941               NaN
# DONAHUE JR JEFFREY M                  875760           1080988
# DUNCAN JOHN H                          77492            371750
# DURAN WILLIAM D                      2093263           1640910
# ECHOLS JOHN B                        2692324           1008941
# ELLIOTT STEVEN                        211725           6678735
# FALLON JAMES B                       3676340           2332399
# FASTOW ANDREW S                      2424083           1794412
# FITZGERALD JAY L                     1414857           1621236
# FOWLER PEGGY                             NaN           1884748
# FOY JOE                               181755            343434
# FREVERT MARK A                      17252530          14622185
# FUGH JOHN L                            50591            176378
# GAHN ROBERT S                         900585            318607
# ...                                      ...               ...
# MORAN MICHAEL P                          NaN            221141
# MORDAUNT KRISTINA M                   628522            208510
# MULLER MARK S                        3202070           1416848
# MURRAY JULIA H                        812194            597461
# NOLES JAMES L                         774401            368705
# OLSON CINDY K                        1321557           2606763
# OVERDYKE JR JERE C                    249787           7307594
# PAI LOU L                            3123383          23817930
# PEREIRA PAULO V. FERRAZ                27942               NaN
# PICKERING MARK R                     1386690             28798
# PIPER GREGORY F                      1737629            880290
# PIRO JIM                                 NaN             47304
# POWERS WILLIAM                           NaN               NaN
# PRENTICE JAMES                        564348           1095040
# REDMOND BRIAN L                       111529           7890324
# REYNOLDS LAWRENCE                     394475           4221891
# RICE KENNETH D                        505050          22542539
# RIEKER PAULA H                       1099100           1918887
# SAVAGE FRANK                            3750               NaN
# SCRIMSHAW MATTHEW                        NaN            759557
# SHANKMAN JEFFREY A                   3038702           2072035
# SHAPIRO RICHARD S                    1057548            987001
# SHARP VICTORIA T                     1576511            494136
# SHELBY REX                           2003885           2493616
# SHERRICK JEFFREY B                       NaN           1832468
# SHERRIFF JOHN R                      4335388           3128982
# SKILLING JEFFREY K                   8682716          26093672
# STABLER FRANK                        1112087            511734
# SULLIVAN-SHAKLOVITZ COLLEEN           999356           1362375
# SUNDE MARTIN                         1545059            698920
# TAYLOR MITCHELL S                    1092663           3745048
# THE TRAVEL AGENCY IN THE PARK         362096               NaN
# THORN TERENCE H                       911453           4817796
# TILNEY ELIZABETH A                    399393           1168042
# TOTAL                              309886585         434509511
# UMANOFF ADAM S                       1130461               NaN
# URQUHART JOHN A                       228656               NaN
# WAKEHAM JOHN                          213071               NaN
# WALLS JR ROBERT H                    1798780           5898997
# WALTERS GARETH W                       87410           1030329
# WASAFF GEORGE                        1034395           2056427
# WESTFAHL RICHARD K                    762135            384930
# WHALEY DAVID A                           NaN             98718
# WHALLEY LAWRENCE G                   4677574           6079137
# WHITE JR THOMAS E                    1934359          15144123
# WINOKUR JR. HERBERT S                  84992               NaN
# WODRASKA JOHN                         189583               NaN
# WROBEL BRUCE                             NaN            139130
# YEAGER F SCOTT                        360300          11884758
# YEAP SOON                              55097            192758
#
# [146 rows x 21 columns]

# %% [markdown]
# # Exercises
# Use `pandas` to answer questions regarding the Enron dataset. If you're uncertain how to do something, feel free to ask questions, look through [the `pandas` documentation](http://pandas.pydata.org/pandas-docs/stable/api.html), or refer to the code examples above!
#
# You can check your solutions to each of these exercises by entering your answer in the corresponding Quiz in the "Datasets and Questions" lesson. I put the corresponding quizzes in parenthesis after each exercise, so you know where to go to check your answers.

# %% [markdown]
# Types of Data Quizzes: Questions 1-6 answer options
#
# - numerical- numerical values (numbers)
# - categorical- limited number of discrete values (category)
# - time series- temporal value (date, timestamp)
# - text- words
# - other

# %% [markdown]
# ## Question 1
# What type of data is salary info? (Quiz: Types of Data 1)
#
# Number

# %% [markdown]
# ## Question 2
# What type of data is job title? (Quiz: Types of Data 2)
#
# Categorical

# %% [markdown]
# ## Question 3
# What type of data is timestamps on emails? (Quiz: Types of Data 3)
#
# time-series

# %% [markdown]
# ## Question 4
# What type of data is contents of emails? (Quiz: Types of Data 4)
#
# text-words

# %% [markdown]
# ## Question 5
# What type of data is number of emails sent by a given person? (Quiz: Types of Data 5)
#
#
# Number

# %% [markdown]
# ## Question 6
# What type of data is to/from fields of emails? (Quiz: Types of Data 6)
#
#
# text-words

# %% [markdown]
# ## Question 7
# How many data points (people) are in the data set? (Quiz: Size of the Enron Dataset)

# %%
len(enron_df.index)
# Out:
# 146

# %% [markdown]
# ## Question 8
# For each person, how many features are available? (Quiz: Features in the Enron Dataset)

# %%
len(enron_df.columns)
# Out:
# 21

# %% [markdown]
# ## Question 9
# How many Persons of Interest (POIs) are in the dataset? (Quiz: Finding POIs in the Enron Data)

# %%
len(enron_df[enron_df['poi']])
# len(enron_df[enron_df['poi'] == False])
# Out:
# 18

# %% [markdown]
# ## Question 10
# We compiled a list of all POI names (in `final_project/poi_names.txt`) and associated email addresses (in `final_project/poi_email_addresses.py`).
#
# How many POI’s were there total? Use the **names** file, not the email addresses, since many folks have more than one address and a few didn’t work for Enron, so we don’t have their emails. (Quiz: How Many POIs Exist?)
#
# **Hint:** Open up the `poi_names.txt` file to see the file format:
#   - the first line is a link to a USA Today article
#   - the second line is blank
#   - subsequent lines have the format: `(•) Lastname, Firstname`
#       - the dot `•` is either "y" (for yes) or "n" (for no), describing if the emails for that POI are available

# %%
poi_names = "final_project/poi_names.txt"

poi_emails = []

poi_first_name = []

poi_last_name = []

with open(poi_names, 'r') as f:
    # skip usa today url
    usa_today_url = f.readline()
    #skip the second blank line
    f.readline()

    for line in f:
        name = line.split(" ")
        print name

        poi_emails.append(name[0][1]=="y")
        poi_first_name.append(name[1][:-1])
        poi_last_name.append(name[2][:-1])


len(poi_first_name)
# Out:
# ['(y)', 'Lay,', 'Kenneth\n']
# ['(y)', 'Skilling,', 'Jeffrey\n']
# ['(n)', 'Howard,', 'Kevin\n']
# ['(n)', 'Krautz,', 'Michael\n']
# ['(n)', 'Yeager,', 'Scott\n']
# ['(n)', 'Hirko,', 'Joseph\n']
# ['(n)', 'Shelby,', 'Rex\n']
# ['(n)', 'Bermingham,', 'David\n']
# ['(n)', 'Darby,', 'Giles\n']
# ['(n)', 'Mulgrew,', 'Gary\n']
# ['(n)', 'Bayley,', 'Daniel\n']
# ['(n)', 'Brown,', 'James\n']
# ['(n)', 'Furst,', 'Robert\n']
# ['(n)', 'Fuhs,', 'William\n']
# ['(n)', 'Causey,', 'Richard\n']
# ['(n)', 'Calger,', 'Christopher\n']
# ['(n)', 'DeSpain,', 'Timothy\n']
# ['(n)', 'Hannon,', 'Kevin\n']
# ['(n)', 'Koenig,', 'Mark\n']
# ['(y)', 'Forney,', 'John\n']
# ['(n)', 'Rice,', 'Kenneth\n']
# ['(n)', 'Rieker,', 'Paula\n']
# ['(n)', 'Fastow,', 'Lea\n']
# ['(n)', 'Fastow,', 'Andrew\n']
# ['(y)', 'Delainey,', 'David\n']
# ['(n)', 'Glisan,', 'Ben\n']
# ['(n)', 'Richter,', 'Jeffrey\n']
# ['(n)', 'Lawyer,', 'Larry\n']
# ['(n)', 'Belden,', 'Timothy\n']
# ['(n)', 'Kopper,', 'Michael\n']
# ['(n)', 'Duncan,', 'David\n']
# ['(n)', 'Bowen,', 'Raymond\n']
# ['(n)', 'Colwell,', 'Wesley\n']
# ['(n)', 'Boyle,', 'Dan\n']
# ['(n)', 'Loehr,', 'Christopher\n']
# 35

# %% [markdown]
# ## Question 11
# What might be a problem with having some POIs missing from our dataset? (Quiz: Problems with Incomplete Data)
#
# Introduces bias

# %% [markdown]
# ## Question 12
# What is the total value of the stock belonging to James Prentice? (Query The Dataset 1)

# %%
print enron_df.columns
print enron_df.index.str.contains("Prentice", case=False)
print enron_df[enron_df.index.str.contains("Prentice", case=False)]
# For text analytics, index.str.contains is useful for text analytics
enron_df[enron_df.index.str.contains("Prentice", case=False)]['total_stock_value']
# Out:
# Index([u'bonus', u'deferral_payments', u'deferred_income', u'director_fees',
#        u'email_address', u'exercised_stock_options', u'expenses',
#        u'from_messages', u'from_poi_to_this_person',
#        u'from_this_person_to_poi', u'loan_advances', u'long_term_incentive',
#        u'other', u'poi', u'restricted_stock', u'restricted_stock_deferred',
#        u'salary', u'shared_receipt_with_poi', u'to_messages',
#        u'total_payments', u'total_stock_value'],
#       dtype='object')
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False]
#                bonus deferral_payments deferred_income director_fees  \
# PRENTICE JAMES   NaN            564348             NaN           NaN
#
#                            email_address exercised_stock_options expenses  \
# PRENTICE JAMES  james.prentice@enron.com                  886231      NaN
#
#                from_messages from_poi_to_this_person from_this_person_to_poi  \
# PRENTICE JAMES           NaN                     NaN                     NaN
#
#                       ...        long_term_incentive other    poi  \
# PRENTICE JAMES        ...                        NaN   NaN  False
#
#                restricted_stock restricted_stock_deferred salary  \
# PRENTICE JAMES           208809                       NaN    NaN
#
#                shared_receipt_with_poi to_messages total_payments  \
# PRENTICE JAMES                     NaN         NaN         564348
#
#                total_stock_value
# PRENTICE JAMES           1095040
#
# [1 rows x 21 columns]
# PRENTICE JAMES    1095040
# Name: total_stock_value, dtype: object

# %% [markdown]
# ## Question 13
# How many email messages do we have from Wesley Colwell to persons of interest? (Query The Dataset 2)

# %%
enron_df[enron_df.index.str.contains("Colwell", case=False)]['from_this_person_to_poi']
# Out:
# COLWELL WESLEY    11
# Name: from_this_person_to_poi, dtype: object

# %% [markdown]
# ## Question 14
# What's the value of stock options exercised by Jeffrey K Skilling? (Query The Dataset 3)

# %%
enron_df[enron_df.index.str.contains("Skilling", case=False)]['exercised_stock_options']
# Out:
# SKILLING JEFFREY K    19250000
# Name: exercised_stock_options, dtype: object

# %% [markdown]
# **Questions 15-18 can be answered by some basic online research**
#
# ## Question 15
# Which of these schemes was Enron **not** involved in? (Quiz: Research the Enron Fraud)
#
# - selling assets to shell companies at the end of each month, and buying them back at the beginning of the next month to hide accounting losses
# - causing electrical grid failures in California
# - illegally obtained a government report that enabled them to corner the market on frozen concentrated orange juice futures
# - conspiring to give a Saudi prince expedited American citizenship
# - a plan in collaboration with Blockbuster movies to stream movies over the internet
#
# ## Question 16
# Who was the CEO of Enron during most of the time that fraud was being perpetrated? (Quiz: Enron CEO)
#
# ## Question 17
# Who was chairman of the Enron board of directors? (Quiz: Enron Chairman)
#
# ## Question 18
# Who was CFO (chief financial officer) of Enron during most of the time that fraud was going on? (Quiz: Enron CFO)

# %% [markdown]
# ## Question 19
# Of these three individuals (Lay, Skilling and Fastow), who took home the most money (largest value of “total_payments” feature)?(Quiz: Follow The Money)
#
# How much money did that person get?

# %%
enron_df[(enron_df.index.str.contains("Lay", case=False)) | \
         (enron_df.index.str.contains("Skilling", case=False)) | \
         (enron_df.index.str.contains("Fastow", case=False))]['total_payments']
# Out:
# FASTOW ANDREW S         2424083
# LAY KENNETH L         103559793
# SKILLING JEFFREY K      8682716
# Name: total_payments, dtype: object

# %% [markdown]
# ## Question 20
# For nearly every person in the dataset, not every feature has a value. How is it denoted when a feature doesn’t have a well-defined value? (Quiz: Unfilled Features)

# %%
enron_df
# Out:
#                                   bonus deferral_payments deferred_income  \
# ALLEN PHILLIP K                 4175000           2869717        -3081055
# BADUM JAMES P                       NaN            178980             NaN
# BANNANTINE JAMES M                  NaN               NaN           -5104
# BAXTER JOHN C                   1200000           1295738        -1386055
# BAY FRANKLIN R                   400000            260455         -201641
# BAZELIDES PHILIP J                  NaN            684694             NaN
# BECK SALLY W                     700000               NaN             NaN
# BELDEN TIMOTHY N                5249999           2144013        -2334434
# BELFER ROBERT                       NaN           -102500             NaN
# BERBERIAN DAVID                     NaN               NaN             NaN
# BERGSIEKER RICHARD P             250000               NaN         -485813
# BHATNAGAR SANJAY                    NaN               NaN             NaN
# BIBI PHILIPPE A                 1000000               NaN             NaN
# BLACHMAN JEREMY M                850000               NaN             NaN
# BLAKE JR. NORMAN P                  NaN               NaN         -113784
# BOWEN JR RAYMOND M              1350000               NaN            -833
# BROWN MICHAEL                       NaN               NaN             NaN
# BUCHANAN HAROLD G                500000               NaN             NaN
# BUTTS ROBERT H                   750000               NaN          -75000
# BUY RICHARD B                    900000            649584         -694862
# CALGER CHRISTOPHER F            1250000               NaN         -262500
# CARTER REBECCA C                 300000               NaN         -159792
# CAUSEY RICHARD A                1000000               NaN         -235000
# CHAN RONNIE                         NaN               NaN          -98784
# CHRISTODOULOU DIOMEDES              NaN               NaN             NaN
# CLINE KENNETH W                     NaN               NaN             NaN
# COLWELL WESLEY                  1200000             27610         -144062
# CORDES WILLIAM R                    NaN               NaN             NaN
# COX DAVID                        800000               NaN          -41250
# CUMBERLAND MICHAEL S             325000               NaN             NaN
# DEFFNER JOSEPH M                 600000               NaN             NaN
# DELAINEY DAVID W                3000000               NaN             NaN
# DERRICK JR. JAMES V              800000               NaN        -1284000
# DETMERING TIMOTHY J              425000            875307         -775241
# DIETRICH JANET R                 600000               NaN             NaN
# DIMICHELE RICHARD G             1000000               NaN             NaN
# DODSON KEITH                      70000               NaN             NaN
# DONAHUE JR JEFFREY M             800000               NaN         -300000
# DUNCAN JOHN H                       NaN               NaN          -25000
# DURAN WILLIAM D                  750000               NaN             NaN
# ECHOLS JOHN B                    200000               NaN             NaN
# ELLIOTT STEVEN                   350000               NaN         -400729
# FALLON JAMES B                  2500000               NaN             NaN
# FASTOW ANDREW S                 1300000               NaN        -1386055
# FITZGERALD JAY L                 350000               NaN             NaN
# FOWLER PEGGY                        NaN               NaN             NaN
# FOY JOE                             NaN            181755             NaN
# FREVERT MARK A                  2000000           6426990        -3367011
# FUGH JOHN L                         NaN             50591             NaN
# GAHN ROBERT S                    509870             73122           -1042
# ...                                 ...               ...             ...
# MORAN MICHAEL P                     NaN               NaN             NaN
# MORDAUNT KRISTINA M              325000               NaN             NaN
# MULLER MARK S                   1100000            842924         -719000
# MURRAY JULIA H                   400000               NaN             NaN
# NOLES JAMES L                       NaN            774401             NaN
# OLSON CINDY K                    750000             77716             NaN
# OVERDYKE JR JERE C                  NaN               NaN             NaN
# PAI LOU L                       1000000               NaN             NaN
# PEREIRA PAULO V. FERRAZ             NaN               NaN         -101250
# PICKERING MARK R                 300000               NaN             NaN
# PIPER GREGORY F                  400000           1130036          -33333
# PIRO JIM                            NaN               NaN             NaN
# POWERS WILLIAM                      NaN               NaN          -17500
# PRENTICE JAMES                      NaN            564348             NaN
# REDMOND BRIAN L                     NaN               NaN             NaN
# REYNOLDS LAWRENCE                100000             51365         -200000
# RICE KENNETH D                  1750000               NaN        -3504386
# RIEKER PAULA H                   700000            214678         -100000
# SAVAGE FRANK                        NaN               NaN         -121284
# SCRIMSHAW MATTHEW                   NaN               NaN             NaN
# SHANKMAN JEFFREY A              2000000               NaN             NaN
# SHAPIRO RICHARD S                650000               NaN             NaN
# SHARP VICTORIA T                 600000            187469             NaN
# SHELBY REX                       200000               NaN           -4167
# SHERRICK JEFFREY B                  NaN               NaN             NaN
# SHERRIFF JOHN R                 1500000               NaN             NaN
# SKILLING JEFFREY K              5600000               NaN             NaN
# STABLER FRANK                    500000               NaN             NaN
# SULLIVAN-SHAKLOVITZ COLLEEN      100000            181993             NaN
# SUNDE MARTIN                     700000               NaN             NaN
# TAYLOR MITCHELL S                600000            227449             NaN
# THE TRAVEL AGENCY IN THE PARK       NaN               NaN             NaN
# THORN TERENCE H                     NaN             16586             NaN
# TILNEY ELIZABETH A               300000               NaN         -575000
# TOTAL                          97343619          32083396       -27992891
# UMANOFF ADAM S                   788750               NaN             NaN
# URQUHART JOHN A                     NaN               NaN          -36666
# WAKEHAM JOHN                        NaN               NaN             NaN
# WALLS JR ROBERT H                850000               NaN             NaN
# WALTERS GARETH W                    NaN             53625             NaN
# WASAFF GEORGE                    325000            831299         -583325
# WESTFAHL RICHARD K                  NaN               NaN          -10800
# WHALEY DAVID A                      NaN               NaN             NaN
# WHALLEY LAWRENCE G              3000000               NaN             NaN
# WHITE JR THOMAS E                450000               NaN             NaN
# WINOKUR JR. HERBERT S               NaN               NaN          -25000
# WODRASKA JOHN                       NaN               NaN             NaN
# WROBEL BRUCE                        NaN               NaN             NaN
# YEAGER F SCOTT                      NaN               NaN             NaN
# YEAP SOON                           NaN               NaN             NaN
#
#                               director_fees                     email_address  \
# ALLEN PHILLIP K                         NaN           phillip.allen@enron.com
# BADUM JAMES P                           NaN                               NaN
# BANNANTINE JAMES M                      NaN        james.bannantine@enron.com
# BAXTER JOHN C                           NaN                               NaN
# BAY FRANKLIN R                          NaN               frank.bay@enron.com
# BAZELIDES PHILIP J                      NaN                               NaN
# BECK SALLY W                            NaN              sally.beck@enron.com
# BELDEN TIMOTHY N                        NaN              tim.belden@enron.com
# BELFER ROBERT                          3285                               NaN
# BERBERIAN DAVID                         NaN         david.berberian@enron.com
# BERGSIEKER RICHARD P                    NaN         rick.bergsieker@enron.com
# BHATNAGAR SANJAY                     137864        sanjay.bhatnagar@enron.com
# BIBI PHILIPPE A                         NaN           philippe.bibi@enron.com
# BLACHMAN JEREMY M                       NaN         jeremy.blachman@enron.com
# BLAKE JR. NORMAN P                   113784                               NaN
# BOWEN JR RAYMOND M                      NaN           raymond.bowen@enron.com
# BROWN MICHAEL                           NaN           michael.brown@enron.com
# BUCHANAN HAROLD G                       NaN           john.buchanan@enron.com
# BUTTS ROBERT H                          NaN               bob.butts@enron.com
# BUY RICHARD B                           NaN                rick.buy@enron.com
# CALGER CHRISTOPHER F                    NaN      christopher.calger@enron.com
# CARTER REBECCA C                        NaN          rebecca.carter@enron.com
# CAUSEY RICHARD A                        NaN          richard.causey@enron.com
# CHAN RONNIE                           98784                               NaN
# CHRISTODOULOU DIOMEDES                  NaN  diomedes.christodoulou@enron.com
# CLINE KENNETH W                         NaN                               NaN
# COLWELL WESLEY                          NaN             wes.colwell@enron.com
# CORDES WILLIAM R                        NaN             bill.cordes@enron.com
# COX DAVID                               NaN                chip.cox@enron.com
# CUMBERLAND MICHAEL S                    NaN                               NaN
# DEFFNER JOSEPH M                        NaN          joseph.deffner@enron.com
# DELAINEY DAVID W                        NaN          david.delainey@enron.com
# DERRICK JR. JAMES V                     NaN           james.derrick@enron.com
# DETMERING TIMOTHY J                     NaN       timothy.detmering@enron.com
# DIETRICH JANET R                        NaN          janet.dietrich@enron.com
# DIMICHELE RICHARD G                     NaN       richard.dimichele@enron.com
# DODSON KEITH                            NaN            keith.dodson@enron.com
# DONAHUE JR JEFFREY M                    NaN            jeff.donahue@enron.com
# DUNCAN JOHN H                        102492                               NaN
# DURAN WILLIAM D                         NaN                 w.duran@enron.com
# ECHOLS JOHN B                           NaN             john.echols@enron.com
# ELLIOTT STEVEN                          NaN          steven.elliott@enron.com
# FALLON JAMES B                          NaN              jim.fallon@enron.com
# FASTOW ANDREW S                         NaN           andrew.fastow@enron.com
# FITZGERALD JAY L                        NaN          jay.fitzgerald@enron.com
# FOWLER PEGGY                            NaN        kulvinder.fowler@enron.com
# FOY JOE                                 NaN               tracy.foy@enron.com
# FREVERT MARK A                          NaN            mark.frevert@enron.com
# FUGH JOHN L                             NaN                               NaN
# GAHN ROBERT S                           NaN                               NaN
# ...                                     ...                               ...
# MORAN MICHAEL P                         NaN           michael.moran@enron.com
# MORDAUNT KRISTINA M                     NaN       kristina.mordaunt@enron.com
# MULLER MARK S                           NaN               s..muller@enron.com
# MURRAY JULIA H                          NaN            julia.murray@enron.com
# NOLES JAMES L                           NaN                               NaN
# OLSON CINDY K                           NaN             cindy.olson@enron.com
# OVERDYKE JR JERE C                      NaN           jere.overdyke@enron.com
# PAI LOU L                               NaN                 lou.pai@enron.com
# PEREIRA PAULO V. FERRAZ              101250                               NaN
# PICKERING MARK R                        NaN          mark.pickering@enron.com
# PIPER GREGORY F                         NaN              greg.piper@enron.com
# PIRO JIM                                NaN                jim.piro@enron.com
# POWERS WILLIAM                        17500              ken.powers@enron.com
# PRENTICE JAMES                          NaN          james.prentice@enron.com
# REDMOND BRIAN L                         NaN           brian.redmond@enron.com
# REYNOLDS LAWRENCE                       NaN                               NaN
# RICE KENNETH D                          NaN                ken.rice@enron.com
# RIEKER PAULA H                          NaN            paula.rieker@enron.com
# SAVAGE FRANK                         125034                               NaN
# SCRIMSHAW MATTHEW                       NaN       matthew.scrimshaw@enron.com
# SHANKMAN JEFFREY A                      NaN        jeffrey.shankman@enron.com
# SHAPIRO RICHARD S                       NaN         richard.shapiro@enron.com
# SHARP VICTORIA T                        NaN             vicki.sharp@enron.com
# SHELBY REX                              NaN              rex.shelby@enron.com
# SHERRICK JEFFREY B                      NaN        jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                         NaN           john.sherriff@enron.com
# SKILLING JEFFREY K                      NaN           jeff.skilling@enron.com
# STABLER FRANK                           NaN           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN             NaN                               NaN
# SUNDE MARTIN                            NaN             marty.sunde@enron.com
# TAYLOR MITCHELL S                       NaN         mitchell.taylor@enron.com
# THE TRAVEL AGENCY IN THE PARK           NaN                               NaN
# THORN TERENCE H                         NaN           terence.thorn@enron.com
# TILNEY ELIZABETH A                      NaN        elizabeth.tilney@enron.com
# TOTAL                               1398517                               NaN
# UMANOFF ADAM S                          NaN            adam.umanoff@enron.com
# URQUHART JOHN A                       36666                               NaN
# WAKEHAM JOHN                         109298                               NaN
# WALLS JR ROBERT H                       NaN               rob.walls@enron.com
# WALTERS GARETH W                        NaN                               NaN
# WASAFF GEORGE                           NaN           george.wasaff@enron.com
# WESTFAHL RICHARD K                      NaN           dick.westfahl@enron.com
# WHALEY DAVID A                          NaN                               NaN
# WHALLEY LAWRENCE G                      NaN            greg.whalley@enron.com
# WHITE JR THOMAS E                       NaN            thomas.white@enron.com
# WINOKUR JR. HERBERT S                108579                               NaN
# WODRASKA JOHN                           NaN           john.wodraska@enron.com
# WROBEL BRUCE                            NaN                               NaN
# YEAGER F SCOTT                          NaN            scott.yeager@enron.com
# YEAP SOON                               NaN                               NaN
#
#                               exercised_stock_options expenses from_messages  \
# ALLEN PHILLIP K                               1729541    13868          2195
# BADUM JAMES P                                  257817     3486           NaN
# BANNANTINE JAMES M                            4046157    56301            29
# BAXTER JOHN C                                 6680544    11200           NaN
# BAY FRANKLIN R                                    NaN   129142           NaN
# BAZELIDES PHILIP J                            1599641      NaN           NaN
# BECK SALLY W                                      NaN    37172          4343
# BELDEN TIMOTHY N                               953136    17355           484
# BELFER ROBERT                                    3285      NaN           NaN
# BERBERIAN DAVID                               1624396    11892           NaN
# BERGSIEKER RICHARD P                              NaN    59175            59
# BHATNAGAR SANJAY                              2604490      NaN            29
# BIBI PHILIPPE A                               1465734    38559            40
# BLACHMAN JEREMY M                              765313    84208            14
# BLAKE JR. NORMAN P                                NaN     1279           NaN
# BOWEN JR RAYMOND M                                NaN    65907            27
# BROWN MICHAEL                                     NaN    49288            41
# BUCHANAN HAROLD G                              825464      600           125
# BUTTS ROBERT H                                    NaN     9410           NaN
# BUY RICHARD B                                 2542813      NaN          1053
# CALGER CHRISTOPHER F                              NaN    35818           144
# CARTER REBECCA C                                  NaN      NaN            15
# CAUSEY RICHARD A                                  NaN    30674            49
# CHAN RONNIE                                       NaN      NaN           NaN
# CHRISTODOULOU DIOMEDES                        5127155      NaN           NaN
# CLINE KENNETH W                                   NaN      NaN           NaN
# COLWELL WESLEY                                    NaN    16514            40
# CORDES WILLIAM R                               651850      NaN            12
# COX DAVID                                      117551    27861            33
# CUMBERLAND MICHAEL S                              NaN    22344           NaN
# DEFFNER JOSEPH M                                17378    41626            74
# DELAINEY DAVID W                              2291113    86174          3069
# DERRICK JR. JAMES V                           8831913    51124           909
# DETMERING TIMOTHY J                           2027865    52255           NaN
# DIETRICH JANET R                              1550019     3475            63
# DIMICHELE RICHARD G                           8191755    35812           NaN
# DODSON KEITH                                      NaN    28164            14
# DONAHUE JR JEFFREY M                           765920    96268            22
# DUNCAN JOHN H                                  371750      NaN           NaN
# DURAN WILLIAM D                               1451869    25785            12
# ECHOLS JOHN B                                  601438    21530           NaN
# ELLIOTT STEVEN                                4890344    78552           NaN
# FALLON JAMES B                                 940257    95924            75
# FASTOW ANDREW S                                   NaN    55921           NaN
# FITZGERALD JAY L                               664461    23870            16
# FOWLER PEGGY                                  1324578      NaN            36
# FOY JOE                                        343434      NaN            13
# FREVERT MARK A                               10433518    86987            21
# FUGH JOHN L                                    176378      NaN           NaN
# GAHN ROBERT S                                   83237    50080           NaN
# ...                                               ...      ...           ...
# MORAN MICHAEL P                                 59539      NaN            19
# MORDAUNT KRISTINA M                               NaN    35018           NaN
# MULLER MARK S                                 1056320      NaN            16
# MURRAY JULIA H                                 400478    57580            45
# NOLES JAMES L                                     NaN      NaN           NaN
# OLSON CINDY K                                 1637034    63791            52
# OVERDYKE JR JERE C                            5266578    18834           NaN
# PAI LOU L                                    15364167    32047           NaN
# PEREIRA PAULO V. FERRAZ                           NaN    27942           NaN
# PICKERING MARK R                                28798    31653            67
# PIPER GREGORY F                                880290    43057           222
# PIRO JIM                                          NaN      NaN            16
# POWERS WILLIAM                                    NaN      NaN            26
# PRENTICE JAMES                                 886231      NaN           NaN
# REDMOND BRIAN L                               7509039    14689           221
# REYNOLDS LAWRENCE                             4160672     8409           NaN
# RICE KENNETH D                               19794175    46950            18
# RIEKER PAULA H                                1635238    33271            82
# SAVAGE FRANK                                      NaN      NaN           NaN
# SCRIMSHAW MATTHEW                              759557      NaN           NaN
# SHANKMAN JEFFREY A                            1441898   178979          2681
# SHAPIRO RICHARD S                              607837   137767          1215
# SHARP VICTORIA T                               281073   116337           136
# SHELBY REX                                    1624396    22884            39
# SHERRICK JEFFREY B                            1426469      NaN            25
# SHERRIFF JOHN R                               1835558      NaN            92
# SKILLING JEFFREY K                           19250000    29336           108
# STABLER FRANK                                     NaN    16514           NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                   1362375      NaN           NaN
# SUNDE MARTIN                                      NaN      NaN            38
# TAYLOR MITCHELL S                             3181250      NaN            29
# THE TRAVEL AGENCY IN THE PARK                     NaN      NaN           NaN
# THORN TERENCE H                               4452476    46145            41
# TILNEY ELIZABETH A                             591250      NaN            19
# TOTAL                                       311764000  5235198           NaN
# UMANOFF ADAM S                                    NaN    53122            18
# URQUHART JOHN A                                   NaN   228656           NaN
# WAKEHAM JOHN                                      NaN   103773           NaN
# WALLS JR ROBERT H                             4346544    50936           146
# WALTERS GARETH W                              1030329    33785           NaN
# WASAFF GEORGE                                 1668260      NaN            30
# WESTFAHL RICHARD K                                NaN    51870           NaN
# WHALEY DAVID A                                  98718      NaN           NaN
# WHALLEY LAWRENCE G                            3282960    57838           556
# WHITE JR THOMAS E                             1297049    81353           NaN
# WINOKUR JR. HERBERT S                             NaN     1413           NaN
# WODRASKA JOHN                                     NaN      NaN           NaN
# WROBEL BRUCE                                   139130      NaN           NaN
# YEAGER F SCOTT                                8308552    53947           NaN
# YEAP SOON                                      192758    55097           NaN
#
#                               from_poi_to_this_person from_this_person_to_poi  \
# ALLEN PHILLIP K                                    47                      65
# BADUM JAMES P                                     NaN                     NaN
# BANNANTINE JAMES M                                 39                       0
# BAXTER JOHN C                                     NaN                     NaN
# BAY FRANKLIN R                                    NaN                     NaN
# BAZELIDES PHILIP J                                NaN                     NaN
# BECK SALLY W                                      144                     386
# BELDEN TIMOTHY N                                  228                     108
# BELFER ROBERT                                     NaN                     NaN
# BERBERIAN DAVID                                   NaN                     NaN
# BERGSIEKER RICHARD P                                4                       0
# BHATNAGAR SANJAY                                    0                       1
# BIBI PHILIPPE A                                    23                       8
# BLACHMAN JEREMY M                                  25                       2
# BLAKE JR. NORMAN P                                NaN                     NaN
# BOWEN JR RAYMOND M                                140                      15
# BROWN MICHAEL                                      13                       1
# BUCHANAN HAROLD G                                   0                       0
# BUTTS ROBERT H                                    NaN                     NaN
# BUY RICHARD B                                     156                      71
# CALGER CHRISTOPHER F                              199                      25
# CARTER REBECCA C                                   29                       7
# CAUSEY RICHARD A                                   58                      12
# CHAN RONNIE                                       NaN                     NaN
# CHRISTODOULOU DIOMEDES                            NaN                     NaN
# CLINE KENNETH W                                   NaN                     NaN
# COLWELL WESLEY                                    240                      11
# CORDES WILLIAM R                                   10                       0
# COX DAVID                                           0                       4
# CUMBERLAND MICHAEL S                              NaN                     NaN
# DEFFNER JOSEPH M                                  115                       4
# DELAINEY DAVID W                                   66                     609
# DERRICK JR. JAMES V                                64                      20
# DETMERING TIMOTHY J                               NaN                     NaN
# DIETRICH JANET R                                  305                      14
# DIMICHELE RICHARD G                               NaN                     NaN
# DODSON KEITH                                       10                       3
# DONAHUE JR JEFFREY M                              188                      11
# DUNCAN JOHN H                                     NaN                     NaN
# DURAN WILLIAM D                                   106                       3
# ECHOLS JOHN B                                     NaN                     NaN
# ELLIOTT STEVEN                                    NaN                     NaN
# FALLON JAMES B                                     42                      37
# FASTOW ANDREW S                                   NaN                     NaN
# FITZGERALD JAY L                                    1                       8
# FOWLER PEGGY                                        0                       0
# FOY JOE                                             0                       0
# FREVERT MARK A                                    242                       6
# FUGH JOHN L                                       NaN                     NaN
# GAHN ROBERT S                                     NaN                     NaN
# ...                                               ...                     ...
# MORAN MICHAEL P                                     0                       0
# MORDAUNT KRISTINA M                               NaN                     NaN
# MULLER MARK S                                      12                       0
# MURRAY JULIA H                                     11                       2
# NOLES JAMES L                                     NaN                     NaN
# OLSON CINDY K                                      20                      15
# OVERDYKE JR JERE C                                NaN                     NaN
# PAI LOU L                                         NaN                     NaN
# PEREIRA PAULO V. FERRAZ                           NaN                     NaN
# PICKERING MARK R                                    7                       0
# PIPER GREGORY F                                    61                      48
# PIRO JIM                                            0                       1
# POWERS WILLIAM                                      0                       0
# PRENTICE JAMES                                    NaN                     NaN
# REDMOND BRIAN L                                   204                      49
# REYNOLDS LAWRENCE                                 NaN                     NaN
# RICE KENNETH D                                     42                       4
# RIEKER PAULA H                                     35                      48
# SAVAGE FRANK                                      NaN                     NaN
# SCRIMSHAW MATTHEW                                 NaN                     NaN
# SHANKMAN JEFFREY A                                 94                      83
# SHAPIRO RICHARD S                                  74                      65
# SHARP VICTORIA T                                   24                       6
# SHELBY REX                                         13                      14
# SHERRICK JEFFREY B                                 39                      18
# SHERRIFF JOHN R                                    28                      23
# SKILLING JEFFREY K                                 88                      30
# STABLER FRANK                                     NaN                     NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                       NaN                     NaN
# SUNDE MARTIN                                       37                      13
# TAYLOR MITCHELL S                                   0                       0
# THE TRAVEL AGENCY IN THE PARK                     NaN                     NaN
# THORN TERENCE H                                     0                       0
# TILNEY ELIZABETH A                                 10                      11
# TOTAL                                             NaN                     NaN
# UMANOFF ADAM S                                     12                       0
# URQUHART JOHN A                                   NaN                     NaN
# WAKEHAM JOHN                                      NaN                     NaN
# WALLS JR ROBERT H                                  17                       0
# WALTERS GARETH W                                  NaN                     NaN
# WASAFF GEORGE                                      22                       7
# WESTFAHL RICHARD K                                NaN                     NaN
# WHALEY DAVID A                                    NaN                     NaN
# WHALLEY LAWRENCE G                                186                      24
# WHITE JR THOMAS E                                 NaN                     NaN
# WINOKUR JR. HERBERT S                             NaN                     NaN
# WODRASKA JOHN                                     NaN                     NaN
# WROBEL BRUCE                                      NaN                     NaN
# YEAGER F SCOTT                                    NaN                     NaN
# YEAP SOON                                         NaN                     NaN
#
#                                      ...        long_term_incentive     other  \
# ALLEN PHILLIP K                      ...                     304805       152
# BADUM JAMES P                        ...                        NaN       NaN
# BANNANTINE JAMES M                   ...                        NaN    864523
# BAXTER JOHN C                        ...                    1586055   2660303
# BAY FRANKLIN R                       ...                        NaN        69
# BAZELIDES PHILIP J                   ...                      93750       874
# BECK SALLY W                         ...                        NaN       566
# BELDEN TIMOTHY N                     ...                        NaN    210698
# BELFER ROBERT                        ...                        NaN       NaN
# BERBERIAN DAVID                      ...                        NaN       NaN
# BERGSIEKER RICHARD P                 ...                     180250    427316
# BHATNAGAR SANJAY                     ...                        NaN    137864
# BIBI PHILIPPE A                      ...                     369721    425688
# BLACHMAN JEREMY M                    ...                     831809       272
# BLAKE JR. NORMAN P                   ...                        NaN       NaN
# BOWEN JR RAYMOND M                   ...                     974293      1621
# BROWN MICHAEL                        ...                        NaN       NaN
# BUCHANAN HAROLD G                    ...                     304805      1215
# BUTTS ROBERT H                       ...                     175000    150656
# BUY RICHARD B                        ...                     769862    400572
# CALGER CHRISTOPHER F                 ...                     375304       486
# CARTER REBECCA C                     ...                      75000       540
# CAUSEY RICHARD A                     ...                     350000    307895
# CHAN RONNIE                          ...                        NaN       NaN
# CHRISTODOULOU DIOMEDES               ...                        NaN       NaN
# CLINE KENNETH W                      ...                        NaN       NaN
# COLWELL WESLEY                       ...                        NaN    101740
# CORDES WILLIAM R                     ...                        NaN       NaN
# COX DAVID                            ...                        NaN       494
# CUMBERLAND MICHAEL S                 ...                     275000       713
# DEFFNER JOSEPH M                     ...                     335349     25553
# DELAINEY DAVID W                     ...                    1294981      1661
# DERRICK JR. JAMES V                  ...                     484000      7482
# DETMERING TIMOTHY J                  ...                     415657      1105
# DIETRICH JANET R                     ...                     556416       473
# DIMICHELE RICHARD G                  ...                     694862    374689
# DODSON KEITH                         ...                        NaN       774
# DONAHUE JR JEFFREY M                 ...                        NaN       891
# DUNCAN JOHN H                        ...                        NaN       NaN
# DURAN WILLIAM D                      ...                    1105218      1568
# ECHOLS JOHN B                        ...                    2234774     53775
# ELLIOTT STEVEN                       ...                        NaN     12961
# FALLON JAMES B                       ...                     374347    401481
# FASTOW ANDREW S                      ...                    1736055    277464
# FITZGERALD JAY L                     ...                     556416    285414
# FOWLER PEGGY                         ...                        NaN       NaN
# FOY JOE                              ...                        NaN       NaN
# FREVERT MARK A                       ...                    1617011   7427621
# FUGH JOHN L                          ...                        NaN       NaN
# GAHN ROBERT S                        ...                        NaN     76547
# ...                                  ...                        ...       ...
# MORAN MICHAEL P                      ...                        NaN       NaN
# MORDAUNT KRISTINA M                  ...                        NaN      1411
# MULLER MARK S                        ...                    1725545       947
# MURRAY JULIA H                       ...                     125000       330
# NOLES JAMES L                        ...                        NaN       NaN
# OLSON CINDY K                        ...                     100000       972
# OVERDYKE JR JERE C                   ...                     135836       176
# PAI LOU L                            ...                        NaN   1829457
# PEREIRA PAULO V. FERRAZ              ...                        NaN       NaN
# PICKERING MARK R                     ...                        NaN       NaN
# PIPER GREGORY F                      ...                        NaN       778
# PIRO JIM                             ...                        NaN       NaN
# POWERS WILLIAM                       ...                        NaN       NaN
# PRENTICE JAMES                       ...                        NaN       NaN
# REDMOND BRIAN L                      ...                        NaN       NaN
# REYNOLDS LAWRENCE                    ...                     156250    202052
# RICE KENNETH D                       ...                    1617011    174839
# RIEKER PAULA H                       ...                        NaN      1950
# SAVAGE FRANK                         ...                        NaN       NaN
# SCRIMSHAW MATTHEW                    ...                        NaN       NaN
# SHANKMAN JEFFREY A                   ...                     554422      1191
# SHAPIRO RICHARD S                    ...                        NaN       705
# SHARP VICTORIA T                     ...                     422158      2401
# SHELBY REX                           ...                        NaN   1573324
# SHERRICK JEFFREY B                   ...                        NaN       NaN
# SHERRIFF JOHN R                      ...                     554422   1852186
# SKILLING JEFFREY K                   ...                    1920000     22122
# STABLER FRANK                        ...                        NaN    356071
# SULLIVAN-SHAKLOVITZ COLLEEN          ...                     554422       162
# SUNDE MARTIN                         ...                     476451    111122
# TAYLOR MITCHELL S                    ...                        NaN       NaN
# THE TRAVEL AGENCY IN THE PARK        ...                        NaN    362096
# THORN TERENCE H                      ...                     200000    426629
# TILNEY ELIZABETH A                   ...                     275000    152055
# TOTAL                                ...                   48521928  42667589
# UMANOFF ADAM S                       ...                        NaN       NaN
# URQUHART JOHN A                      ...                        NaN       NaN
# WAKEHAM JOHN                         ...                        NaN       NaN
# WALLS JR ROBERT H                    ...                     540751         2
# WALTERS GARETH W                     ...                        NaN       NaN
# WASAFF GEORGE                        ...                     200000      1425
# WESTFAHL RICHARD K                   ...                     256191    401130
# WHALEY DAVID A                       ...                        NaN       NaN
# WHALLEY LAWRENCE G                   ...                     808346    301026
# WHITE JR THOMAS E                    ...                        NaN   1085463
# WINOKUR JR. HERBERT S                ...                        NaN       NaN
# WODRASKA JOHN                        ...                        NaN    189583
# WROBEL BRUCE                         ...                        NaN       NaN
# YEAGER F SCOTT                       ...                        NaN    147950
# YEAP SOON                            ...                        NaN       NaN
#
#                                  poi restricted_stock  \
# ALLEN PHILLIP K                False           126027
# BADUM JAMES P                  False              NaN
# BANNANTINE JAMES M             False          1757552
# BAXTER JOHN C                  False          3942714
# BAY FRANKLIN R                 False           145796
# BAZELIDES PHILIP J             False              NaN
# BECK SALLY W                   False           126027
# BELDEN TIMOTHY N                True           157569
# BELFER ROBERT                  False              NaN
# BERBERIAN DAVID                False           869220
# BERGSIEKER RICHARD P           False           659249
# BHATNAGAR SANJAY               False         -2604490
# BIBI PHILIPPE A                False           378082
# BLACHMAN JEREMY M              False           189041
# BLAKE JR. NORMAN P             False              NaN
# BOWEN JR RAYMOND M              True           252055
# BROWN MICHAEL                  False              NaN
# BUCHANAN HAROLD G              False           189041
# BUTTS ROBERT H                 False           417619
# BUY RICHARD B                  False           901657
# CALGER CHRISTOPHER F            True           126027
# CARTER REBECCA C               False           307301
# CAUSEY RICHARD A                True          2502063
# CHAN RONNIE                    False            32460
# CHRISTODOULOU DIOMEDES         False           950730
# CLINE KENNETH W                False           662086
# COLWELL WESLEY                  True           698242
# CORDES WILLIAM R               False           386335
# COX DAVID                      False           378082
# CUMBERLAND MICHAEL S           False           207940
# DEFFNER JOSEPH M               False           141833
# DELAINEY DAVID W                True          1323148
# DERRICK JR. JAMES V            False          1787380
# DETMERING TIMOTHY J            False           315068
# DIETRICH JANET R               False           315068
# DIMICHELE RICHARD G            False           126027
# DODSON KEITH                   False              NaN
# DONAHUE JR JEFFREY M           False           315068
# DUNCAN JOHN H                  False              NaN
# DURAN WILLIAM D                False           189041
# ECHOLS JOHN B                  False           407503
# ELLIOTT STEVEN                 False          1788391
# FALLON JAMES B                 False          1392142
# FASTOW ANDREW S                 True          1794412
# FITZGERALD JAY L               False           956775
# FOWLER PEGGY                   False           560170
# FOY JOE                        False              NaN
# FREVERT MARK A                 False          4188667
# FUGH JOHN L                    False              NaN
# GAHN ROBERT S                  False           235370
# ...                              ...              ...
# MORAN MICHAEL P                False           161602
# MORDAUNT KRISTINA M            False           208510
# MULLER MARK S                  False           360528
# MURRAY JULIA H                 False           196983
# NOLES JAMES L                  False           463261
# OLSON CINDY K                  False           969729
# OVERDYKE JR JERE C             False          2041016
# PAI LOU L                      False          8453763
# PEREIRA PAULO V. FERRAZ        False              NaN
# PICKERING MARK R               False              NaN
# PIPER GREGORY F                False           409554
# PIRO JIM                       False            47304
# POWERS WILLIAM                 False              NaN
# PRENTICE JAMES                 False           208809
# REDMOND BRIAN L                False           381285
# REYNOLDS LAWRENCE              False           201483
# RICE KENNETH D                  True          2748364
# RIEKER PAULA H                  True           283649
# SAVAGE FRANK                   False              NaN
# SCRIMSHAW MATTHEW              False              NaN
# SHANKMAN JEFFREY A             False           630137
# SHAPIRO RICHARD S              False           379164
# SHARP VICTORIA T               False           213063
# SHELBY REX                      True           869220
# SHERRICK JEFFREY B             False           405999
# SHERRIFF JOHN R                False          1293424
# SKILLING JEFFREY K              True          6843672
# STABLER FRANK                  False           511734
# SULLIVAN-SHAKLOVITZ COLLEEN    False              NaN
# SUNDE MARTIN                   False           698920
# TAYLOR MITCHELL S              False           563798
# THE TRAVEL AGENCY IN THE PARK  False              NaN
# THORN TERENCE H                False           365320
# TILNEY ELIZABETH A             False           576792
# TOTAL                          False        130322299
# UMANOFF ADAM S                 False              NaN
# URQUHART JOHN A                False              NaN
# WAKEHAM JOHN                   False              NaN
# WALLS JR ROBERT H              False          1552453
# WALTERS GARETH W               False              NaN
# WASAFF GEORGE                  False           388167
# WESTFAHL RICHARD K             False           384930
# WHALEY DAVID A                 False              NaN
# WHALLEY LAWRENCE G             False          2796177
# WHITE JR THOMAS E              False         13847074
# WINOKUR JR. HERBERT S          False              NaN
# WODRASKA JOHN                  False              NaN
# WROBEL BRUCE                   False              NaN
# YEAGER F SCOTT                  True          3576206
# YEAP SOON                      False              NaN
#
#                               restricted_stock_deferred    salary  \
# ALLEN PHILLIP K                                 -126027    201955
# BADUM JAMES P                                       NaN       NaN
# BANNANTINE JAMES M                              -560222       477
# BAXTER JOHN C                                       NaN    267102
# BAY FRANKLIN R                                   -82782    239671
# BAZELIDES PHILIP J                                  NaN     80818
# BECK SALLY W                                        NaN    231330
# BELDEN TIMOTHY N                                    NaN    213999
# BELFER ROBERT                                     44093       NaN
# BERBERIAN DAVID                                     NaN    216582
# BERGSIEKER RICHARD P                                NaN    187922
# BHATNAGAR SANJAY                               15456290       NaN
# BIBI PHILIPPE A                                     NaN    213625
# BLACHMAN JEREMY M                                   NaN    248546
# BLAKE JR. NORMAN P                                  NaN       NaN
# BOWEN JR RAYMOND M                                  NaN    278601
# BROWN MICHAEL                                       NaN       NaN
# BUCHANAN HAROLD G                                   NaN    248017
# BUTTS ROBERT H                                      NaN    261516
# ...
# RIEKER PAULA H                                      NaN    249201
# SAVAGE FRANK                                        NaN       NaN
# SCRIMSHAW MATTHEW                                   NaN       NaN
# SHANKMAN JEFFREY A                                  NaN    304110
# SHAPIRO RICHARD S                                   NaN    269076
# SHARP VICTORIA T                                    NaN    248146
# SHELBY REX                                          NaN    211844
# SHERRICK JEFFREY B                                  NaN       NaN
# SHERRIFF JOHN R                                     NaN    428780
# SKILLING JEFFREY K                                  NaN   1111258
# STABLER FRANK                                       NaN    239502
# SULLIVAN-SHAKLOVITZ COLLEEN                         NaN    162779
# SUNDE MARTIN                                        NaN    257486
# TAYLOR MITCHELL S                                   NaN    265214
# THE TRAVEL AGENCY IN THE PARK                       NaN       NaN
# THORN TERENCE H                                     NaN    222093
# TILNEY ELIZABETH A                                  NaN    247338
# TOTAL                                          -7576788  26704229
# UMANOFF ADAM S                                      NaN    288589
# URQUHART JOHN A                                     NaN       NaN
# WAKEHAM JOHN                                        NaN       NaN
# WALLS JR ROBERT H                                   NaN    357091
# WALTERS GARETH W                                    NaN       NaN
# WASAFF GEORGE                                       NaN    259996
# WESTFAHL RICHARD K                                  NaN     63744
# WHALEY DAVID A                                      NaN       NaN
# WHALLEY LAWRENCE G                                  NaN    510364
# WHITE JR THOMAS E                                   NaN    317543
# WINOKUR JR. HERBERT S                               NaN       NaN
# WODRASKA JOHN                                       NaN       NaN
# WROBEL BRUCE                                        NaN       NaN
# YEAGER F SCOTT                                      NaN    158403
# YEAP SOON                                           NaN       NaN
#
#                               shared_receipt_with_poi to_messages  \
# ALLEN PHILLIP K                                  1407        2902
# BADUM JAMES P                                     NaN         NaN
# BANNANTINE JAMES M                                465         566
# BAXTER JOHN C                                     NaN         NaN
# BAY FRANKLIN R                                    NaN         NaN
# BAZELIDES PHILIP J                                NaN         NaN
# BECK SALLY W                                     2639        7315
# BELDEN TIMOTHY N                                 5521        7991
# BELFER ROBERT                                     NaN         NaN
# BERBERIAN DAVID                                   NaN         NaN
# BERGSIEKER RICHARD P                              233         383
# BHATNAGAR SANJAY                                  463         523
# BIBI PHILIPPE A                                  1336        1607
# BLACHMAN JEREMY M                                2326        2475
# BLAKE JR. NORMAN P                                NaN         NaN
# BOWEN JR RAYMOND M                               1593        1858
# BROWN MICHAEL                                     761        1486
# BUCHANAN HAROLD G                                  23        1088
# BUTTS ROBERT H                                    NaN         NaN
# BUY RICHARD B                                    2333        3523
# CALGER CHRISTOPHER F                             2188        2598
# CARTER REBECCA C                                  196         312
# CAUSEY RICHARD A                                 1585        1892
# CHAN RONNIE                                       NaN         NaN
# CHRISTODOULOU DIOMEDES                            NaN         NaN
# CLINE KENNETH W                                   NaN         NaN
# COLWELL WESLEY                                   1132        1758
# CORDES WILLIAM R                                   58         764
# COX DAVID                                          71         102
# CUMBERLAND MICHAEL S                              NaN         NaN
# DEFFNER JOSEPH M                                  552         714
# DELAINEY DAVID W                                 2097        3093
# DERRICK JR. JAMES V                              1401        2181
# DETMERING TIMOTHY J                               NaN         NaN
# DIETRICH JANET R                                 1902        2572
# DIMICHELE RICHARD G                               NaN         NaN
# DODSON KEITH                                      114         176
# DONAHUE JR JEFFREY M                              772         865
# DUNCAN JOHN H                                     NaN         NaN
# DURAN WILLIAM D                                   599         904
# ECHOLS JOHN B                                     NaN         NaN
# ELLIOTT STEVEN                                    NaN         NaN
# FALLON JAMES B                                   1604        1755
# FASTOW ANDREW S                                   NaN         NaN
# FITZGERALD JAY L                                  723         936
# FOWLER PEGGY                                       10         517
# FOY JOE                                             2          57
# FREVERT MARK A                                   2979        3275
# FUGH JOHN L                                       NaN         NaN
# GAHN ROBERT S                                     NaN         NaN
# ...                                               ...         ...
# MORAN MICHAEL P                                   127         672
# MORDAUNT KRISTINA M                               NaN         NaN
# MULLER MARK S                                     114         136
# MURRAY JULIA H                                    395        2192
# NOLES JAMES L                                     NaN         NaN
# OLSON CINDY K                                     856        1184
# OVERDYKE JR JERE C                                NaN         NaN
# PAI LOU L                                         NaN         NaN
# PEREIRA PAULO V. FERRAZ                           NaN         NaN
# PICKERING MARK R                                  728         898
# PIPER GREGORY F                                   742        1238
# PIRO JIM                                            3          58
# POWERS WILLIAM                                     12         653
# PRENTICE JAMES                                    NaN         NaN
# REDMOND BRIAN L                                  1063        1671
# REYNOLDS LAWRENCE                                 NaN         NaN
# RICE KENNETH D                                    864         905
# RIEKER PAULA H                                   1258        1328
# SAVAGE FRANK                                      NaN         NaN
# SCRIMSHAW MATTHEW                                 NaN         NaN
# SHANKMAN JEFFREY A                               1730        3221
# SHAPIRO RICHARD S                                4527       15149
# SHARP VICTORIA T                                 2477        3136
# SHELBY REX                                         91         225
# SHERRICK JEFFREY B                                583         613
# SHERRIFF JOHN R                                  2103        3187
# SKILLING JEFFREY K                               2042        3627
# STABLER FRANK                                     NaN         NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                       NaN         NaN
# SUNDE MARTIN                                     2565        2647
# TAYLOR MITCHELL S                                 300         533
# THE TRAVEL AGENCY IN THE PARK                     NaN         NaN
# THORN TERENCE H                                    73         266
# TILNEY ELIZABETH A                                379         460
# TOTAL                                             NaN         NaN
# UMANOFF ADAM S                                     41         111
# URQUHART JOHN A                                   NaN         NaN
# WAKEHAM JOHN                                      NaN         NaN
# WALLS JR ROBERT H                                 215         671
# WALTERS GARETH W                                  NaN         NaN
# WASAFF GEORGE                                     337         400
# WESTFAHL RICHARD K                                NaN         NaN
# WHALEY DAVID A                                    NaN         NaN
# WHALLEY LAWRENCE G                               3920        6019
# WHITE JR THOMAS E                                 NaN         NaN
# WINOKUR JR. HERBERT S                             NaN         NaN
# WODRASKA JOHN                                     NaN         NaN
# WROBEL BRUCE                                      NaN         NaN
# YEAGER F SCOTT                                    NaN         NaN
# YEAP SOON                                         NaN         NaN
#
#                               total_payments total_stock_value
# ALLEN PHILLIP K                      4484442           1729541
# BADUM JAMES P                         182466            257817
# BANNANTINE JAMES M                    916197           5243487
# BAXTER JOHN C                        5634343          10623258
# BAY FRANKLIN R                        827696             63014
# BAZELIDES PHILIP J                    860136           1599641
# BECK SALLY W                          969068            126027
# BELDEN TIMOTHY N                     5501630           1110705
# BELFER ROBERT                         102500            -44093
# BERBERIAN DAVID                       228474           2493616
# BERGSIEKER RICHARD P                  618850            659249
# BHATNAGAR SANJAY                    15456290               NaN
# BIBI PHILIPPE A                      2047593           1843816
# BLACHMAN JEREMY M                    2014835            954354
# BLAKE JR. NORMAN P                      1279               NaN
# BOWEN JR RAYMOND M                   2669589            252055
# BROWN MICHAEL                          49288               NaN
# BUCHANAN HAROLD G                    1054637           1014505
# BUTTS ROBERT H                       1271582            417619
# BUY RICHARD B                        2355702           3444470
# CALGER CHRISTOPHER F                 1639297            126027
# CARTER REBECCA C                      477557               NaN
# CAUSEY RICHARD A                     1868758           2502063
# CHAN RONNIE                              NaN               NaN
# CHRISTODOULOU DIOMEDES                   NaN           6077885
# CLINE KENNETH W                          NaN            189518
# COLWELL WESLEY                       1490344            698242
# CORDES WILLIAM R                         NaN           1038185
# COX DAVID                            1101393            495633
# CUMBERLAND MICHAEL S                  807956            207940
# DEFFNER JOSEPH M                     1208649            159211
# DELAINEY DAVID W                     4747979           3614261
# DERRICK JR. JAMES V                   550981           8831913
# DETMERING TIMOTHY J                  1204583           2027865
# DIETRICH JANET R                     1410464           1865087
# DIMICHELE RICHARD G                  2368151           8317782
# DODSON KEITH                          319941               NaN
# DONAHUE JR JEFFREY M                  875760           1080988
# DUNCAN JOHN H                          77492            371750
# DURAN WILLIAM D                      2093263           1640910
# ECHOLS JOHN B                        2692324           1008941
# ELLIOTT STEVEN                        211725           6678735
# FALLON JAMES B                       3676340           2332399
# FASTOW ANDREW S                      2424083           1794412
# FITZGERALD JAY L                     1414857           1621236
# FOWLER PEGGY                             NaN           1884748
# FOY JOE                               181755            343434
# FREVERT MARK A                      17252530          14622185
# FUGH JOHN L                            50591            176378
# GAHN ROBERT S                         900585            318607
# ...                                      ...               ...
# MORAN MICHAEL P                          NaN            221141
# MORDAUNT KRISTINA M                   628522            208510
# MULLER MARK S                        3202070           1416848
# MURRAY JULIA H                        812194            597461
# NOLES JAMES L                         774401            368705
# OLSON CINDY K                        1321557           2606763
# OVERDYKE JR JERE C                    249787           7307594
# PAI LOU L                            3123383          23817930
# PEREIRA PAULO V. FERRAZ                27942               NaN
# PICKERING MARK R                     1386690             28798
# PIPER GREGORY F                      1737629            880290
# PIRO JIM                                 NaN             47304
# POWERS WILLIAM                           NaN               NaN
# PRENTICE JAMES                        564348           1095040
# REDMOND BRIAN L                       111529           7890324
# REYNOLDS LAWRENCE                     394475           4221891
# RICE KENNETH D                        505050          22542539
# RIEKER PAULA H                       1099100           1918887
# SAVAGE FRANK                            3750               NaN
# SCRIMSHAW MATTHEW                        NaN            759557
# SHANKMAN JEFFREY A                   3038702           2072035
# SHAPIRO RICHARD S                    1057548            987001
# SHARP VICTORIA T                     1576511            494136
# SHELBY REX                           2003885           2493616
# SHERRICK JEFFREY B                       NaN           1832468
# SHERRIFF JOHN R                      4335388           3128982
# SKILLING JEFFREY K                   8682716          26093672
# STABLER FRANK                        1112087            511734
# SULLIVAN-SHAKLOVITZ COLLEEN           999356           1362375
# SUNDE MARTIN                         1545059            698920
# TAYLOR MITCHELL S                    1092663           3745048
# THE TRAVEL AGENCY IN THE PARK         362096               NaN
# THORN TERENCE H                       911453           4817796
# TILNEY ELIZABETH A                    399393           1168042
# TOTAL                              309886585         434509511
# UMANOFF ADAM S                       1130461               NaN
# URQUHART JOHN A                       228656               NaN
# WAKEHAM JOHN                          213071               NaN
# WALLS JR ROBERT H                    1798780           5898997
# WALTERS GARETH W                       87410           1030329
# WASAFF GEORGE                        1034395           2056427
# WESTFAHL RICHARD K                    762135            384930
# WHALEY DAVID A                           NaN             98718
# WHALLEY LAWRENCE G                   4677574           6079137
# WHITE JR THOMAS E                    1934359          15144123
# WINOKUR JR. HERBERT S                  84992               NaN
# WODRASKA JOHN                         189583               NaN
# WROBEL BRUCE                             NaN            139130
# YEAGER F SCOTT                        360300          11884758
# YEAP SOON                              55097            192758
#
# [146 rows x 21 columns]

# %% [markdown]
# ## Question 21
# How many folks in this dataset have a quantified salary? What about a known email address? (Quiz: Dealing with Unfilled Features)

# %%
# you cannot leave the == sign blank because the values are not boolean values
len(enron_df[enron_df['salary'] != 'NaN'])
# Out:
# 95

# %% [markdown]
# ## More Magic Functions
#
# In the Jupyter Notebook `lesson 1`, we introduced our first [Magic Function](http://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magics-explained):
#
# `%matplotlib inline`
#
# That allowed us to generate plots using `matplotlib.pyplot` that appeared directly within our Jupyter Notebook! Earlier in this notebook, we also introduced the Magic Function:
#
# `%cd "..."`
#
# Replacing the ellipses in the above Magic Function with the path of the **ud120-projects** repo allowed us to change the working directory for this Jupyter Notebook session. Let's learn one last Magic Function:
#
# `%load filename.py`
#
# This allows us to quickly load python code from the file `filename.py` into the current cell.
#
# **Run** the cell below to execute the Magic Function `%load tools/feature_format.py` from the **ud120-projects** repo. What happens?

# %%
# %load tools/feature_format.py
#!/usr/bin/python

""" 
    A general tool for converting data from the
    dictionary format to an (n x k) python list that's 
    ready for training an sklearn algorithm

    n--no. of key-value pairs in dictonary
    k--no. of features being extracted

    dictionary keys are names of persons in dataset
    dictionary values are dictionaries, where each
        key-value pair in the dict is the name
        of a feature, and its value for that person

    In addition to converting a dictionary to a numpy 
    array, you may want to separate the labels from the
    features--this is what targetFeatureSplit is for

    so, if you want to have the poi label as the target,
    and the features you want to use are the person's
    salary and bonus, here's what you would do:

    feature_list = ["poi", "salary", "bonus"] 
    data_array = featureFormat( data_dictionary, feature_list )
    label, features = targetFeatureSplit(data_array)

    the line above (targetFeatureSplit) assumes that the
    label is the _first_ item in feature_list--very important
    that poi is listed first!
"""


import numpy as np

def featureFormat( dictionary, features, remove_NaN=True, remove_all_zeroes=True, remove_any_zeroes=False, sort_keys = False):
    """ convert dictionary to numpy array of features
        remove_NaN = True will convert "NaN" string to 0.0
        remove_all_zeroes = True will omit any data points for which
            all the features you seek are 0.0
        remove_any_zeroes = True will omit any data points for which
            any of the features you seek are 0.0
        sort_keys = True sorts keys by alphabetical order. Setting the value as
            a string opens the corresponding pickle file with a preset key
            order (this is used for Python 3 compatibility, and sort_keys
            should be left as False for the course mini-projects).
        NOTE: first feature is assumed to be 'poi' and is not checked for
            removal for zero or missing values.
    """


    return_list = []

    # Key order - first branch is for Python 3 compatibility on mini-projects,
    # second branch is for compatibility on final project.
    if isinstance(sort_keys, str):
        import pickle
        keys = pickle.load(open(sort_keys, "rb"))
    elif sort_keys:
        keys = sorted(dictionary.keys())
    else:
        keys = dictionary.keys()

    for key in keys:
        tmp_list = []
        for feature in features:
            try:
                dictionary[key][feature]
            except KeyError:
                print "error: key ", feature, " not present"
                return
            value = dictionary[key][feature]
            if value=="NaN" and remove_NaN:
                value = 0
            tmp_list.append( float(value) )

        # Logic for deciding whether or not to add the data point.
        append = True
        # exclude 'poi' class as criteria.
        if features[0] == 'poi':
            test_list = tmp_list[1:]
        else:
            test_list = tmp_list
        ### if all features are zero and you want to remove
        ### data points that are all zero, do that here
        if remove_all_zeroes:
            append = False
            for item in test_list:
                if item != 0 and item != "NaN":
                    append = True
                    break
        ### if any features for a given data point are zero
        ### and you want to remove data points with any zeroes,
        ### handle that here
        if remove_any_zeroes:
            if 0 in test_list or "NaN" in test_list:
                append = False
        ### Append the data point if flagged for addition.
        if append:
            return_list.append( np.array(tmp_list) )

    return np.array(return_list)


def targetFeatureSplit( data ):
    """ 
        given a numpy array like the one returned from
        featureFormat, separate out the first feature
        and put it into its own list (this should be the 
        quantity you want to predict)

        return targets and features as separate lists

        (sklearn can generally handle both lists and numpy arrays as 
        input formats when training/predicting)
    """

    target = []
    features = []
    for item in data:
        target.append( item[0] )
        features.append( item[1:] )

    return target, features

# %% [markdown]
# You should see that the Magic Function `%load tools/feature_format.py` copies the contents of `feature_format.py` into the same cell, below the magic command. Additionally, the Magic Function `%load tools/feature_format.py` is now commented out. Note that you've **copied** the contents of `feature_format.py` into the cell with the Magic Function, but you need to run the cell a second time to actually **execute** the code.
#
# If you want to try another `%load` Magic Function, **run** the cell below to load the contents of `poi_email_addresses.py` to this Notebook.

# %%
# %load final_project/poi_email_addresses.py
def poiEmails():
    email_list = ["kenneth_lay@enron.net",    
            "kenneth_lay@enron.com",
            "klay.enron@enron.com",
            "kenneth.lay@enron.com", 
            "klay@enron.com",
            "layk@enron.com",
            "chairman.ken@enron.com",
            "jeffreyskilling@yahoo.com",
            "jeff_skilling@enron.com",
            "jskilling@enron.com",
            "effrey.skilling@enron.com",
            "skilling@enron.com",
            "jeffrey.k.skilling@enron.com",
            "jeff.skilling@enron.com",
            "kevin_a_howard.enronxgate.enron@enron.net",
            "kevin.howard@enron.com",
            "kevin.howard@enron.net",
            "kevin.howard@gcm.com",
            "michael.krautz@enron.com"
            "scott.yeager@enron.com",
            "syeager@fyi-net.com",
            "scott_yeager@enron.net",
            "syeager@flash.net",
            "joe'.'hirko@enron.com", 
            "joe.hirko@enron.com", 
            "rex.shelby@enron.com", 
            "rex.shelby@enron.nt", 
            "rex_shelby@enron.net",
            "jbrown@enron.com",
            "james.brown@enron.com", 
            "rick.causey@enron.com", 
            "richard.causey@enron.com", 
            "rcausey@enron.com",
            "calger@enron.com",
            "chris.calger@enron.com", 
            "christopher.calger@enron.com", 
            "ccalger@enron.com",
            "tim_despain.enronxgate.enron@enron.net", 
            "tim.despain@enron.com",
            "kevin_hannon@enron.com", 
            "kevin'.'hannon@enron.com", 
            "kevin_hannon@enron.net", 
            "kevin.hannon@enron.com",
            "mkoenig@enron.com", 
            "mark.koenig@enron.com",
            "m..forney@enron.com",
            "ken'.'rice@enron.com", 
            "ken.rice@enron.com",
            "ken_rice@enron.com", 
            "ken_rice@enron.net",
            "paula.rieker@enron.com",
            "prieker@enron.com", 
            "andrew.fastow@enron.com", 
            "lfastow@pdq.net", 
            "andrew.s.fastow@enron.com", 
            "lfastow@pop.pdq.net", 
            "andy.fastow@enron.com",
            "david.w.delainey@enron.com", 
            "delainey.dave@enron.com", 
            "'delainey@enron.com", 
            "david.delainey@enron.com", 
            "'david.delainey'@enron.com", 
            "dave.delainey@enron.com", 
            "delainey'.'david@enron.com",
            "ben.glisan@enron.com", 
            "bglisan@enron.com", 
            "ben_f_glisan@enron.com", 
            "ben'.'glisan@enron.com",
            "jeff.richter@enron.com", 
            "jrichter@nwlink.com",
            "lawrencelawyer@aol.com", 
            "lawyer'.'larry@enron.com", 
            "larry_lawyer@enron.com", 
            "llawyer@enron.com", 
            "larry.lawyer@enron.com", 
            "lawrence.lawyer@enron.com",
            "tbelden@enron.com", 
            "tim.belden@enron.com", 
            "tim_belden@pgn.com", 
            "tbelden@ect.enron.com",
            "michael.kopper@enron.com",
            "dave.duncan@enron.com", 
            "dave.duncan@cipco.org", 
            "duncan.dave@enron.com",
            "ray.bowen@enron.com", 
            "raymond.bowen@enron.com", 
            "'bowen@enron.com",
            "wes.colwell@enron.com",
            "dan.boyle@enron.com",
            "cloehr@enron.com", 
            "chris.loehr@enron.com"
        ]
    return email_list

# %% [markdown]
# A couple last helpful hints about Magic Functions:
#   - You can learn more about Magic Functions at any time with the Magic Function `%magic`
#   - You can get the list of available Magic Functions by the Magic Function `%lsmagic`
#   - You can learn about any Magic Function by typing a question mark after it, *e.g.* `%load?`
#
# **Try it below!**

# %%
# %magic

# %% [markdown]
# # Optional Exercises -- Missing POIs
# As you saw a little while ago, not every POI has an entry in the dataset (e.g. Michael Krautz). That’s because the dataset was created using the financial data you can find in `../final_project/enron61702insiderpay.pdf`, which is missing some POI’s (those absences propagated through to the final dataset). On the other hand, for many of these “missing” POI’s, we do have emails.
#
# While it would be straightforward to add these POI’s and their email information to the E+F dataset, and just put “NaN” for their financial information, this could introduce a subtle problem. You will walk through that here.
#
# Again, you can check your solutions to each of these exercises by entering your answer in the corresponding Quiz in the "Datasets and Questions" lesson. I put the corresponding quizzes in parenthesis after each exercise, so you know where to go to check your answers.
#
# ## Question 1
# How many people in the E+F dataset (as it currently exists) have “NaN” for their total payments? What percentage of people in the dataset as a whole is this? (Quiz: Missing POIs 1 (Optional))

# %%
enron_df.columns
# Out:
# Index([u'bonus', u'deferral_payments', u'deferred_income', u'director_fees',
#        u'email_address', u'exercised_stock_options', u'expenses',
#        u'from_messages', u'from_poi_to_this_person',
#        u'from_this_person_to_poi', u'loan_advances', u'long_term_incentive',
#        u'other', u'poi', u'restricted_stock', u'restricted_stock_deferred',
#        u'salary', u'shared_receipt_with_poi', u'to_messages',
#        u'total_payments', u'total_stock_value'],
#       dtype='object')

# %%
len(enron_df[enron_df['total_payments'] == "NaN"])
# Out:
# 21

# %%
len(enron_df['total_payments'])
# Out:
# 146

# %%
(21.0/146.0)*100.0
# Out:
# 14.383561643835616

# %% [markdown]
# ## Question 2
# How many POIs in the E+F dataset have “NaN” for their total payments? What percentage of POI’s as a whole is this? (Quiz: Missing POIs 2 (Optional))

# %%
enron_df[(enron_df['poi'] == True) & (enron_df['total_payments'] == "NaN")]
# Out:
# Empty DataFrame
# Columns: [bonus, deferral_payments, deferred_income, director_fees, email_address, exercised_stock_options, expenses, from_messages, from_poi_to_this_person, from_this_person_to_poi, loan_advances, long_term_incentive, other, poi, restricted_stock, restricted_stock_deferred, salary, shared_receipt_with_poi, to_messages, total_payments, total_stock_value]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Question 3
#
# If a machine learning algorithm were to use total_payments as a feature, would you expect it to associate a “NaN” value with POIs or non-POIs? (Quiz: Missing POIs 3 (Optional))
#
# Non-POIs

# %% [markdown]
# ## Question 4
#
# If you added in, say, 10 more data points which were all POI’s, and put “NaN” for the total payments for those folks, the numbers you just calculated would change.
#
# What is the new number of people of the dataset? What is the new number of folks with “NaN” for total payments? (Quiz: Missing POIs 4 (Optional))

# %%
len(enron_df) + 10
# Out:
# 156

# %%
len(enron_df[enron_df['total_payments'] == "NaN"]) +10
# Out:
# 31

# %% [markdown]
# ## Question 5
#
# What is the new number of POI’s in the dataset? What is the new number of POI’s with NaN for total_payments? (Quiz: Missing POIs 5 (Optional))

# %%
enron_df[(enron_df['poi'] == True) & (enron_df['total_payments'] == "NaN")]
# enron_df['poi'][enron_df['total_payments'] == "NaN"]
# Out:
# Empty DataFrame
# Columns: [bonus, deferral_payments, deferred_income, director_fees, email_address, exercised_stock_options, expenses, from_messages, from_poi_to_this_person, from_this_person_to_poi, loan_advances, long_term_incentive, other, poi, restricted_stock, restricted_stock_deferred, salary, shared_receipt_with_poi, to_messages, total_payments, total_stock_value]
# Index: []
#
# [0 rows x 21 columns]

# %%
enron_df.shape
# Out:
# (146, 21)

# %% [markdown]
# ## Question 6
#
# Once the new data points are added, do you think a supervised classification algorithm might interpret “NaN” for total_payments as a clue that someone is a POI? (Quiz: Missing POIs 6 (Optional))
